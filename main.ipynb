# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\ASUS\\.vscode\\lib.pr.py\\data\\clean\\retail_sales_cleaned.csv")

# %%
Sales_by_category=df.groupby("Category")["Total Spent"].sum()
plt.figure(figsize=(10,6))
plt.bar(Sales_by_category.index,Sales_by_category,color="red")
plt.xlabel("Category")
plt.ylabel("Total Spent")
plt.title("Sales by Category")
plt.show()

# %%
df.dtypes
# Out:
# Transaction ID       object
# Customer ID          object
# Category             object
# Item                 object
# Price Per Unit      float64
# Quantity            float64
# Total Spent         float64
# Payment Method       object
# Location             object
# Transaction Date     object
# Discount Applied     object
# dtype: object

# %%
filter=df["Quantity"].notnull() & df["Price Per Unit"].isnull() & df["Total Spent"].notnull()

# %%
df[["Price Per Unit","Quantity","Total Spent"]].isnull().sum()
# Out:
# Price Per Unit    609
# Quantity          604
# Total Spent       604
# dtype: int64

# %%
df.loc[filter,"Price Per Unit"]=df.loc[filter,"Total Spent"]/df.loc[filter,"Quantity"]

# %%
df[["Quantity", "Price Per Unit", "Total Spent"]].isna().sum()
# Out:
# Quantity          604
# Price Per Unit      0
# Total Spent       604
# dtype: int64

# %%
df["Item"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12570    False
# 12571    False
# 12572    False
# 12573    False
# 12574    False
# Name: Item, Length: 12575, dtype: bool

# %%
f_i2=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==5.0) & (df["Item"].isnull())]
f_i2
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 216      TXN_7804271     CUST_22  Patisserie  NaN             5.0       8.0
# 627      TXN_9923470     CUST_21  Patisserie  NaN             5.0       NaN
# 1378     TXN_1276885     CUST_23  Patisserie  NaN             5.0       NaN
# 6675     TXN_6364752     CUST_23  Patisserie  NaN             5.0       NaN
# 7023     TXN_5037301     CUST_21  Patisserie  NaN             5.0       9.0
# 7319     TXN_3503862     CUST_07  Patisserie  NaN             5.0       9.0
# 9087     TXN_1051223     CUST_08  Patisserie  NaN             5.0       9.0
# 10220    TXN_6087492     CUST_24  Patisserie  NaN             5.0       3.0
# 10757    TXN_5842704     CUST_01  Patisserie  NaN             5.0       6.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 216           40.0            Cash    Online       2023-02-10              NaN
# ...

# %%
df.loc[f_i2.index,"Item"]="Item_1_PAT"

# %%
from matplotlib.pylab import f


f_i3=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==8.0) & (df["Item"].isnull())]
f_i3
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 813     TXN_1972761     CUST_23  Patisserie  NaN             8.0      10.0
# 4588    TXN_2118875     CUST_12  Patisserie  NaN             8.0       NaN
# 5139    TXN_5171717     CUST_05  Patisserie  NaN             8.0       6.0
# 5146    TXN_3586844     CUST_13  Patisserie  NaN             8.0       4.0
# 8077    TXN_6771885     CUST_25  Patisserie  NaN             8.0       NaN
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 813          80.0     Credit Card  In-store       2024-10-24              NaN
# 4588          NaN  Digital Wallet  In-store       2023-07-13              NaN
# 5139         48.0     Credit Card    Online       2023-06-19             True
# 5146         32.0            Cash  In-store       2024-11-05             True
# 8077          NaN  Digital Wallet    Online       2025-01-04            False

# %%
df.loc[f_i3.index,"Item"]="Item_3_PAT"

# %%
f_i1=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
f_i1
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 5        TXN_7482416     CUST_09  Patisserie  NaN            20.0      10.0
# 730      TXN_8482271     CUST_23  Patisserie  NaN            20.0       NaN
# 1794     TXN_8531399     CUST_18  Patisserie  NaN            20.0       NaN
# 2131     TXN_8293398     CUST_19  Patisserie  NaN            20.0       NaN
# 4008     TXN_7354091     CUST_22  Patisserie  NaN            20.0       NaN
# 9599     TXN_8686018     CUST_07  Patisserie  NaN            20.0       8.0
# 10342    TXN_1208593     CUST_21  Patisserie  NaN            20.0       NaN
# 10755    TXN_5568136     CUST_04  Patisserie  NaN            20.0       8.0
# 11995    TXN_3871513     CUST_15  Patisserie  NaN            20.0       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 5            200.0     Credit Card    Online       2023-11-30              NaN
# ...

# %%
df.loc[f_i1.index,"Item"]="Item_11_PAT"

# %%
f_i4=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
f_i4
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 829      TXN_4445756     CUST_15  Patisserie  NaN            41.0       4.0
# 1369     TXN_7075100     CUST_20  Patisserie  NaN            41.0       NaN
# 6389     TXN_1228408     CUST_01  Patisserie  NaN            41.0       NaN
# 7397     TXN_6730526     CUST_20  Patisserie  NaN            41.0       NaN
# 9235     TXN_7965748     CUST_08  Patisserie  NaN            41.0       8.0
# 9337     TXN_5992097     CUST_17  Patisserie  NaN            41.0       NaN
# 10001    TXN_3943422     CUST_19  Patisserie  NaN            41.0       NaN
# 11401    TXN_1595090     CUST_19  Patisserie  NaN            41.0       6.0
# 12462    TXN_5573824     CUST_16  Patisserie  NaN            41.0       NaN
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 829          164.0     Credit Card  In-store       2023-10-26              NaN
# ...

# %%
df.loc[f_i4.index,"Item"]="Item_25_PAT"

# %%
f_23=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==21.5) & (df["Item"].isnull())]
f_23
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 3832     TXN_4567294     CUST_21  Patisserie  NaN            21.5       NaN
# 4952     TXN_5125110     CUST_09  Patisserie  NaN            21.5       NaN
# 6375     TXN_6412787     CUST_11  Patisserie  NaN            21.5       2.0
# 7084     TXN_6133268     CUST_13  Patisserie  NaN            21.5       NaN
# 8656     TXN_6852237     CUST_02  Patisserie  NaN            21.5       1.0
# 8806     TXN_2910944     CUST_24  Patisserie  NaN            21.5       NaN
# 10986    TXN_9478901     CUST_11  Patisserie  NaN            21.5       7.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3832           NaN  Digital Wallet    Online       2022-03-28            False
# 4952           NaN  Digital Wallet  In-store       2024-08-13            False
# 6375          43.0  Digital Wallet    Online       2023-04-06            False
# ...

# %%
df.loc[f_23.index,"Item"]="Item_12_PAT"

# %%
f_22=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==18.5) & (df["Item"].isnull())]
f_22
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 2757     TXN_6186202     CUST_14  Patisserie  NaN            18.5       NaN
# 6883     TXN_5473528     CUST_16  Patisserie  NaN            18.5       NaN
# 12027    TXN_4145243     CUST_08  Patisserie  NaN            18.5      10.0
# 12387    TXN_7014462     CUST_24  Patisserie  NaN            18.5       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2757           NaN  Digital Wallet  In-store       2023-02-25              NaN
# 6883           NaN     Credit Card    Online       2023-12-03            False
# 12027        185.0            Cash    Online       2024-12-08              NaN
# 12387         37.0     Credit Card    Online       2024-11-29            False

# %%
df.loc[f_22.index,"Item"]="Item_10_PAT"

# %%
f_21=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
f_21
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 4681    TXN_5202455     CUST_09  Patisserie  NaN            26.0       1.0
# 5751    TXN_8494360     CUST_04  Patisserie  NaN            26.0       2.0
# 7207    TXN_5771988     CUST_22  Patisserie  NaN            26.0       NaN
# 8646    TXN_4168865     CUST_11  Patisserie  NaN            26.0       NaN
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 4681         26.0           Cash    Online       2022-05-22            False
# 5751         52.0    Credit Card    Online       2024-09-27              NaN
# 7207          NaN    Credit Card  In-store       2023-04-07            False
# 8646          NaN           Cash    Online       2023-12-03            False

# %%
df.loc[f_21.index,"Item"]="Item_15_PAT"

# %%
f_20=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
f_20
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 2023    TXN_1985138     CUST_12  Patisserie  NaN            11.0       NaN
# 3163    TXN_5599747     CUST_19  Patisserie  NaN            11.0       NaN
# 6203    TXN_9247444     CUST_21  Patisserie  NaN            11.0       NaN
# 9477    TXN_1164094     CUST_09  Patisserie  NaN            11.0       3.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2023          NaN  Digital Wallet  In-store       2023-01-31            False
# 3163          NaN     Credit Card    Online       2022-05-15             True
# 6203          NaN  Digital Wallet  In-store       2022-03-20            False
# 9477         33.0  Digital Wallet  In-store       2024-07-29              NaN

# %%
df.loc[f_20.index,"Item"]="Item_5_PAT"

# %%
f_19=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
f_19
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 4583     TXN_2758823     CUST_17  Patisserie  NaN            14.0       9.0
# 8404     TXN_3246313     CUST_23  Patisserie  NaN            14.0       NaN
# 8468     TXN_8714514     CUST_04  Patisserie  NaN            14.0       7.0
# 9921     TXN_4684828     CUST_06  Patisserie  NaN            14.0       4.0
# 11746    TXN_2444942     CUST_09  Patisserie  NaN            14.0       8.0
# 12068    TXN_8970327     CUST_06  Patisserie  NaN            14.0       NaN
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 4583         126.0  Digital Wallet  In-store       2024-01-06              NaN
# 8404           NaN  Digital Wallet    Online       2024-01-11              NaN
# 8468          98.0  Digital Wallet  In-store       2022-08-19              NaN
# 9921          56.0     Credit Card  In-store       2023-06-04             True
# ...

# %%
df.loc[f_19.index,"Item"]="	Item_7_PAT"

# %%
f_18=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==39.5) & (df["Item"].isnull())]
f_18
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 2661     TXN_4118493     CUST_24  Patisserie  NaN            39.5       NaN
# 5380     TXN_6024315     CUST_18  Patisserie  NaN            39.5       3.0
# 6006     TXN_6397507     CUST_22  Patisserie  NaN            39.5       8.0
# 7648     TXN_7171953     CUST_11  Patisserie  NaN            39.5       NaN
# 7950     TXN_3521719     CUST_22  Patisserie  NaN            39.5       NaN
# 8102     TXN_5179270     CUST_20  Patisserie  NaN            39.5       2.0
# 8424     TXN_9945945     CUST_11  Patisserie  NaN            39.5       3.0
# 9299     TXN_3017691     CUST_14  Patisserie  NaN            39.5       NaN
# 11074    TXN_4581027     CUST_10  Patisserie  NaN            39.5       NaN
# 11686    TXN_1834624     CUST_25  Patisserie  NaN            39.5       NaN
#
#        Total Spent Payment Method  Location Transaction Date Discount Applied
# ...

# %%
df.loc[f_18.index,"Item"]="Item_24_PAT"

# %%
f_17=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
f_17
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 2930    TXN_9977844     CUST_18  Patisserie  NaN            36.5       NaN
# 3703    TXN_2090388     CUST_10  Patisserie  NaN            36.5       7.0
# 4568    TXN_6434099     CUST_25  Patisserie  NaN            36.5       NaN
# 4943    TXN_8390000     CUST_07  Patisserie  NaN            36.5       NaN
# 9647    TXN_2119863     CUST_24  Patisserie  NaN            36.5      10.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2930          NaN  Digital Wallet  In-store       2022-12-27             True
# 3703        255.5  Digital Wallet  In-store       2023-11-26             True
# 4568          NaN            Cash    Online       2024-08-08              NaN
# 4943          NaN            Cash  In-store       2022-11-09              NaN
# 9647        365.0            Cash    Online       2024-12-24             True

# %%
df.loc[f_17.index,"Item"]="Item_13_PAT"

# %%
f_i16=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
f_i16
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 3426    TXN_1482356     CUST_01  Patisserie  NaN            17.0       7.0
# 5203    TXN_4271313     CUST_12  Patisserie  NaN            17.0       NaN
# 6517    TXN_9682433     CUST_16  Patisserie  NaN            17.0       1.0
# 7046    TXN_1376742     CUST_24  Patisserie  NaN            17.0       NaN
# 9082    TXN_8581857     CUST_05  Patisserie  NaN            17.0       NaN
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3426        119.0  Digital Wallet  In-store       2022-10-24              NaN
# 5203          NaN            Cash    Online       2024-12-09            False
# 6517         17.0     Credit Card    Online       2024-11-29             True
# 7046          NaN     Credit Card    Online       2024-10-20             True
# 9082          NaN            Cash    Online       2024-08-20              NaN

# %%
df.loc[f_i16.index,"Item"]="Item_12_PAT"

# %%
f_i15=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
f_i15
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 3413     TXN_3216751     CUST_17  Patisserie  NaN            29.0      10.0
# 3894     TXN_4344596     CUST_17  Patisserie  NaN            29.0       NaN
# 4041     TXN_1402550     CUST_15  Patisserie  NaN            29.0       NaN
# 5321     TXN_4525178     CUST_12  Patisserie  NaN            29.0       7.0
# 5491     TXN_1415403     CUST_22  Patisserie  NaN            29.0       NaN
# 6856     TXN_9158283     CUST_21  Patisserie  NaN            29.0       NaN
# 7453     TXN_8416020     CUST_02  Patisserie  NaN            29.0       NaN
# 7912     TXN_1443512     CUST_19  Patisserie  NaN            29.0       NaN
# 10823    TXN_3631452     CUST_12  Patisserie  NaN            29.0       7.0
# 11441    TXN_3171724     CUST_18  Patisserie  NaN            29.0       NaN
# 11632    TXN_3964699     CUST_15  Patisserie  NaN            29.0       NaN
#
# ...

# %%
df.loc[f_i15.index,"Item"]="Item_17_PAT"

# %%
f_i14=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
f_i14
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 2665     TXN_3811015     CUST_24  Patisserie  NaN            33.5       NaN
# 3180     TXN_5895413     CUST_21  Patisserie  NaN            33.5       2.0
# 3856     TXN_8127777     CUST_14  Patisserie  NaN            33.5       NaN
# 8721     TXN_7026911     CUST_23  Patisserie  NaN            33.5       8.0
# 9865     TXN_4862692     CUST_12  Patisserie  NaN            33.5       NaN
# 10714    TXN_8186737     CUST_08  Patisserie  NaN            33.5       5.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2665           NaN            Cash    Online       2022-02-04            False
# 3180          67.0  Digital Wallet  In-store       2024-04-29              NaN
# 3856           NaN  Digital Wallet  In-store       2023-02-27              NaN
# 8721         268.0     Credit Card  In-store       2022-12-23             True
# ...

# %%
df.loc[f_i14.index,"Item"]="Item_20_PAT"

# %%
f_i13=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==32.0) & (df["Item"].isnull())]
f_i13
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 3132    TXN_2850753     CUST_16  Patisserie  NaN            32.0       4.0
# 6622    TXN_1425560     CUST_23  Patisserie  NaN            32.0      10.0
# 8233    TXN_2223571     CUST_24  Patisserie  NaN            32.0       9.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3132        128.0            Cash  In-store       2024-01-10              NaN
# 6622        320.0  Digital Wallet  In-store       2023-02-02              NaN
# 8233        288.0     Credit Card  In-store       2022-11-14             True

# %%
df.loc[f_i13.index,"Item"]="Item_19_PAT"

# %%
f_i12=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==24.5) & (df["Item"].isnull())]
f_i12
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 1888     TXN_2026101     CUST_10  Patisserie  NaN            24.5       NaN
# 2240     TXN_5763933     CUST_07  Patisserie  NaN            24.5       NaN
# 2349     TXN_4028997     CUST_03  Patisserie  NaN            24.5       5.0
# 2803     TXN_3419658     CUST_02  Patisserie  NaN            24.5       9.0
# 2872     TXN_1882050     CUST_06  Patisserie  NaN            24.5       NaN
# 4467     TXN_1495602     CUST_17  Patisserie  NaN            24.5      10.0
# 6403     TXN_7710993     CUST_17  Patisserie  NaN            24.5       1.0
# 6772     TXN_9521709     CUST_12  Patisserie  NaN            24.5      10.0
# 6975     TXN_6015868     CUST_07  Patisserie  NaN            24.5       NaN
# 7041     TXN_7478863     CUST_22  Patisserie  NaN            24.5       2.0
# 9652     TXN_9856733     CUST_03  Patisserie  NaN            24.5       NaN
# ...

# %%
df.loc[f_i12.index,"Item"]="Item_14_PAT"

# %%
f_i11=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
f_i11
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 1943     TXN_4887526     CUST_01  Patisserie  NaN             6.5       3.0
# 2441     TXN_8589807     CUST_21  Patisserie  NaN             6.5       NaN
# 8936     TXN_1814757     CUST_01  Patisserie  NaN             6.5       NaN
# 11174    TXN_5266615     CUST_20  Patisserie  NaN             6.5       NaN
# 11821    TXN_5259819     CUST_19  Patisserie  NaN             6.5       5.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1943          19.5            Cash  In-store       2023-03-03            False
# 2441           NaN  Digital Wallet    Online       2022-09-09              NaN
# 8936           NaN            Cash  In-store       2024-08-18              NaN
# 11174          NaN  Digital Wallet  In-store       2024-04-10              NaN
# 11821         32.5     Credit Card  In-store       2022-02-18              NaN

# %%
df.loc[f_i11.index,"Item"]="Item_2_PAT"

# %%
f_i10=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
f_i10
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 83       TXN_4532214     CUST_25  Patisserie  NaN            15.5       NaN
# 1619     TXN_5386745     CUST_01  Patisserie  NaN            15.5       8.0
# 2129     TXN_4114556     CUST_21  Patisserie  NaN            15.5       3.0
# 3141     TXN_3909836     CUST_14  Patisserie  NaN            15.5       NaN
# 4240     TXN_7346385     CUST_10  Patisserie  NaN            15.5       4.0
# 8221     TXN_6920044     CUST_09  Patisserie  NaN            15.5       NaN
# 10122    TXN_7684996     CUST_15  Patisserie  NaN            15.5       NaN
# 10146    TXN_5225733     CUST_02  Patisserie  NaN            15.5       8.0
# 10942    TXN_9675839     CUST_09  Patisserie  NaN            15.5       2.0
# 12300    TXN_2252968     CUST_17  Patisserie  NaN            15.5       NaN
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# ...

# %%
df.loc[f_i10.index,"Item"]="Item_8_PAT"

# %%
f_i9=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
f_i9
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 1406     TXN_5315119     CUST_10  Patisserie  NaN             9.5       3.0
# 3352     TXN_3462517     CUST_01  Patisserie  NaN             9.5       NaN
# 3833     TXN_2514543     CUST_20  Patisserie  NaN             9.5       NaN
# 4304     TXN_5103418     CUST_02  Patisserie  NaN             9.5       NaN
# 6005     TXN_5266941     CUST_03  Patisserie  NaN             9.5       NaN
# 8775     TXN_6211037     CUST_20  Patisserie  NaN             9.5       7.0
# 9387     TXN_8444157     CUST_11  Patisserie  NaN             9.5       NaN
# 11436    TXN_9868145     CUST_15  Patisserie  NaN             9.5       NaN
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1406          28.5  Digital Wallet    Online       2024-09-01              NaN
# 3352           NaN     Credit Card  In-store       2024-02-01              NaN
# ...

# %%
df.loc[f_i9.index,"Item"]="Item_4_PAT"

# %%
f_i8=df[(df["Category"]=="Patisserie") &(df["Price Per Unit"]==23.0)&(df["Item"].isnull())]
f_i8
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 34       TXN_1621497     CUST_06  Patisserie  NaN            23.0       NaN
# 5539     TXN_7061960     CUST_12  Patisserie  NaN            23.0       NaN
# 6401     TXN_7323366     CUST_23  Patisserie  NaN            23.0       NaN
# 9517     TXN_3768715     CUST_12  Patisserie  NaN            23.0       7.0
# 11657    TXN_9478937     CUST_05  Patisserie  NaN            23.0       NaN
# 11845    TXN_7177193     CUST_09  Patisserie  NaN            23.0       7.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 34             NaN            Cash  In-store       2023-02-18              NaN
# 5539           NaN  Digital Wallet    Online       2022-12-26            False
# 6401           NaN     Credit Card  In-store       2022-11-04            False
# 9517         161.0            Cash    Online       2023-12-24             True
# ...

# %%
df.loc[f_i8.index,"Item"]="Item_13_PAT"

# %%
f_i7=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
f_i7
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 1396    TXN_5136594     CUST_14  Patisserie  NaN            30.5       7.0
# 6462    TXN_6325212     CUST_03  Patisserie  NaN            30.5       8.0
# 8308    TXN_5599144     CUST_05  Patisserie  NaN            30.5       NaN
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1396        213.5     Credit Card  In-store       2022-03-23            False
# 6462        244.0  Digital Wallet  In-store       2023-06-07              NaN
# 8308          NaN            Cash  In-store       2022-09-11              NaN

# %%
df.loc[f_i7.index,"Item"]="Item_18_PAT"

# %%
f_i6=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]== 38.0) & (df["Item"].isnull())]
f_i6
# Out:
#       Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 970      TXN_1995311     CUST_23  Patisserie  NaN            38.0       NaN
# 984      TXN_8322817     CUST_23  Patisserie  NaN            38.0       8.0
# 1235     TXN_8221101     CUST_18  Patisserie  NaN            38.0       6.0
# 2573     TXN_3729060     CUST_07  Patisserie  NaN            38.0       6.0
# 3924     TXN_9345275     CUST_09  Patisserie  NaN            38.0       5.0
# 5183     TXN_6823305     CUST_20  Patisserie  NaN            38.0       9.0
# 6063     TXN_1255913     CUST_21  Patisserie  NaN            38.0       1.0
# 8166     TXN_2407302     CUST_14  Patisserie  NaN            38.0       NaN
# 8871     TXN_6749795     CUST_12  Patisserie  NaN            38.0       NaN
# 9329     TXN_8552028     CUST_13  Patisserie  NaN            38.0       NaN
# 12416    TXN_7072261     CUST_19  Patisserie  NaN            38.0       NaN
#
# ...

# %%
df.loc[f_i6.index,"Item"]="Item_23_PAT"

# %%
f_i5=df[(df["Category"]=="Patisserie") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
f_i5
# Out:
#      Transaction ID Customer ID    Category Item  Price Per Unit  Quantity  \
# 864     TXN_2843259     CUST_24  Patisserie  NaN            27.5       1.0
# 3462    TXN_9900913     CUST_25  Patisserie  NaN            27.5       NaN
# 8950    TXN_9295319     CUST_07  Patisserie  NaN            27.5       NaN
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 864          27.5  Digital Wallet  In-store       2023-03-25             True
# 3462          NaN            Cash  In-store       2023-11-15              NaN
# 8950          NaN     Credit Card  In-store       2023-06-04              NaN

# %%
df.loc[f_i5.index,"Item"]="Item_16_PAT"

# %%
rem=df["Quantity"].isnull() & df["Total Spent"].isnull()

# %%
rowrem=df[rem].index

# %%
df.drop(rowrem,inplace=True)

# %%
df["Quantity"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Total Spent"].isna().sum()
# Out:
# np.int64(0)

# %%
m_20=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
m_20
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 2396     TXN_4640422     CUST_05  Milk Products  NaN            20.0
# 7578     TXN_6845710     CUST_03  Milk Products  NaN            20.0
# 10783    TXN_4718422     CUST_04  Milk Products  NaN            20.0
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 2396        3.0         60.0     Credit Card  In-store       2023-03-22
# 7578        2.0         40.0  Digital Wallet    Online       2024-11-23
# 10783       1.0         20.0            Cash    Online       2023-05-26
#
#       Discount Applied
# 2396              True
# 7578               NaN
# 10783              NaN

# %%
df.loc[m_20.index,"Item"]="Item_11_MILK"

# %%
m_21=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
m_21
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 4377    TXN_3087440     CUST_10  Milk Products  NaN            29.0       7.0
# 5610    TXN_1518090     CUST_15  Milk Products  NaN            29.0       4.0
# 6231    TXN_5916658     CUST_11  Milk Products  NaN            29.0       2.0
# 9247    TXN_1310254     CUST_20  Milk Products  NaN            29.0       8.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 4377        203.0            Cash    Online       2024-06-11              NaN
# 5610        116.0     Credit Card    Online       2022-03-06              NaN
# 6231         58.0  Digital Wallet  In-store       2024-05-11            False
# 9247        232.0  Digital Wallet    Online       2022-03-16             True

# %%
df.loc[m_21.index,"Item"]="Item_17_MILK"

# %%
m_22=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==38.0) & (df["Item"].isnull())]
m_22
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 11708    TXN_7107634     CUST_24  Milk Products  NaN            38.0
#
#        Quantity  Total Spent  Payment Method Location Transaction Date  \
# 11708       3.0        114.0  Digital Wallet   Online       2022-05-16
#
#       Discount Applied
# 11708            False

# %%
df.loc[m_22.index,"Item"]="Item_23_MILK"

# %%
m_17=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
m_17
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 2178    TXN_1892483     CUST_22  Milk Products  NaN            26.0       9.0
#
#       Total Spent Payment Method Location Transaction Date Discount Applied
# 2178        234.0           Cash   Online       2023-08-31             True

# %%
df.loc[m_17.index,"Item"]="Item_15_MILK"

# %%
m_18=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==32.0) & (df["Item"].isnull())]
m_18
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 2201     TXN_1943695     CUST_09  Milk Products  NaN            32.0
# 2804     TXN_9957512     CUST_21  Milk Products  NaN            32.0
# 3354     TXN_5802934     CUST_23  Milk Products  NaN            32.0
# 5774     TXN_1996371     CUST_10  Milk Products  NaN            32.0
# 7391     TXN_2854112     CUST_24  Milk Products  NaN            32.0
# 10927    TXN_5324237     CUST_19  Milk Products  NaN            32.0
# 10991    TXN_5444047     CUST_21  Milk Products  NaN            32.0
# 11597    TXN_2065846     CUST_19  Milk Products  NaN            32.0
# 11699    TXN_3969761     CUST_03  Milk Products  NaN            32.0
# 11839    TXN_2143826     CUST_05  Milk Products  NaN            32.0
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 2201        8.0        256.0     Credit Card  In-store       2023-04-04
# ...

# %%
df.loc[m_18.index,"Item"]="Item_19_MILK"

# %%
m_19=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==39.5) & (df["Item"].isnull())]
m_19
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 2256    TXN_3203228     CUST_09  Milk Products  NaN            39.5       1.0
# 2727    TXN_3247249     CUST_10  Milk Products  NaN            39.5       7.0
# 8928    TXN_1809957     CUST_04  Milk Products  NaN            39.5       9.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2256         39.5  Digital Wallet  In-store       2023-01-23             True
# 2727        276.5  Digital Wallet    Online       2023-01-13              NaN
# 8928        355.5     Credit Card    Online       2022-10-12             True

# %%
df.loc[m_19.index,"Item"]="Item_24_MILK"

# %%
m_16=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
m_16
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 2153    TXN_5338814     CUST_06  Milk Products  NaN            41.0      10.0
# 9966    TXN_6314299     CUST_19  Milk Products  NaN            41.0       6.0
#
#       Total Spent  Payment Method Location Transaction Date Discount Applied
# 2153        410.0  Digital Wallet   Online       2023-03-13            False
# 9966        246.0     Credit Card   Online       2022-02-14              NaN

# %%
df.loc[m_16.index,"Item"]="Item_25_MILK"

# %%
m_15=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
m_15
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 1555     TXN_1396754     CUST_18  Milk Products  NaN            15.5
# 1586     TXN_4850024     CUST_01  Milk Products  NaN            15.5
# 10240    TXN_4703736     CUST_16  Milk Products  NaN            15.5
# 12174    TXN_8227236     CUST_07  Milk Products  NaN            15.5
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 1555        4.0         62.0  Digital Wallet  In-store       2022-05-07
# 1586        1.0         15.5            Cash    Online       2022-09-30
# 10240       4.0         62.0  Digital Wallet    Online       2023-05-27
# 12174       4.0         62.0  Digital Wallet    Online       2024-05-12
#
#       Discount Applied
# 1555              True
# 1586              True
# 10240            False
# 12174             True

# %%
df.loc[m_15.index,"Item"]="Item_8_MILK"

# %%
m_14=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==12.5) & (df["Item"].isnull())]
m_14
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 1394    TXN_3019913     CUST_18  Milk Products  NaN            12.5      10.0
# 4854    TXN_9758083     CUST_05  Milk Products  NaN            12.5       7.0
# 5742    TXN_2745229     CUST_22  Milk Products  NaN            12.5       8.0
# 7605    TXN_3033931     CUST_09  Milk Products  NaN            12.5       1.0
# 9698    TXN_6027273     CUST_01  Milk Products  NaN            12.5       1.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1394        125.0            Cash    Online       2024-02-16             True
# 4854         87.5            Cash    Online       2022-08-11            False
# 5742        100.0     Credit Card    Online       2024-12-10              NaN
# 7605         12.5            Cash  In-store       2023-08-17              NaN
# 9698         12.5  Digital Wallet  In-store       2023-03-20              NaN

# %%
df.loc[m_14.index,"Item"]="Item_6_MILK"

# %%
m_13=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==8.0) & (df["Item"].isnull())]
m_13
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 1236    TXN_8508332     CUST_13  Milk Products  NaN             8.0      10.0
# 3122    TXN_4602911     CUST_13  Milk Products  NaN             8.0       7.0
# 6858    TXN_2046922     CUST_21  Milk Products  NaN             8.0       5.0
# 8447    TXN_2168164     CUST_05  Milk Products  NaN             8.0       5.0
# 9221    TXN_5796230     CUST_03  Milk Products  NaN             8.0       5.0
# 9288    TXN_7852595     CUST_21  Milk Products  NaN             8.0       1.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1236         80.0  Digital Wallet  In-store       2022-06-23              NaN
# 3122         56.0     Credit Card  In-store       2023-07-17            False
# 6858         40.0            Cash  In-store       2023-11-26            False
# 8447         40.0     Credit Card  In-store       2024-08-26             True
# ...

# %%
df.loc[m_13.index,"Item"]="Item_3_MILK"

# %%
m_12=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==5.0) & (df["Item"].isnull())]
m_12
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 1148    TXN_8954821     CUST_14  Milk Products  NaN             5.0       9.0
# 1932    TXN_1818683     CUST_10  Milk Products  NaN             5.0       5.0
# 2416    TXN_2442204     CUST_13  Milk Products  NaN             5.0       9.0
# 6576    TXN_9464343     CUST_09  Milk Products  NaN             5.0       7.0
# 7202    TXN_3575373     CUST_17  Milk Products  NaN             5.0       9.0
# 7881    TXN_3957917     CUST_09  Milk Products  NaN             5.0       5.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1148         45.0  Digital Wallet  In-store       2024-06-12              NaN
# 1932         25.0     Credit Card  In-store       2022-07-12              NaN
# 2416         45.0     Credit Card    Online       2024-07-06            False
# 6576         35.0  Digital Wallet    Online       2022-11-11            False
# ...

# %%
df.loc[m_12.index,"Item"]="Item_1_MILK"

# %%
m_1=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
m_1
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 11      TXN_5422631     CUST_09  Milk Products  NaN             6.5       8.0
# 3441    TXN_5730630     CUST_25  Milk Products  NaN             6.5       5.0
# 4300    TXN_3038270     CUST_18  Milk Products  NaN             6.5      10.0
# 4915    TXN_6958546     CUST_16  Milk Products  NaN             6.5       2.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 11           52.0  Digital Wallet  In-store       2025-01-12             True
# 3441         32.5  Digital Wallet  In-store       2023-12-04             True
# 4300         65.0  Digital Wallet    Online       2023-09-24            False
# 4915         13.0            Cash  In-store       2023-11-08              NaN

# %%
df.loc[m_1.index,"Item"]="Item_2_MILK"

# %%
m_2=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
m_2
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 17       TXN_9634894     CUST_15  Milk Products  NaN            27.5
# 631      TXN_8935391     CUST_16  Milk Products  NaN            27.5
# 666      TXN_2028333     CUST_18  Milk Products  NaN            27.5
# 3149     TXN_2756540     CUST_21  Milk Products  NaN            27.5
# 6133     TXN_3396886     CUST_12  Milk Products  NaN            27.5
# 8218     TXN_8332080     CUST_08  Milk Products  NaN            27.5
# 10444    TXN_5520385     CUST_24  Milk Products  NaN            27.5
# 11568    TXN_6442349     CUST_17  Milk Products  NaN            27.5
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 17         10.0        275.0  Digital Wallet    Online       2022-04-17
# 631         1.0         27.5     Credit Card    Online       2022-09-06
# 666         4.0        110.0  Digital Wallet  In-store       2024-07-28
# ...

# %%
df.loc[m_2.index,"Item"]="Item_16_MILK"

# %%
m_3=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
m_3
# Out:
#    Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 21    TXN_8685338     CUST_15  Milk Products  NaN            35.0       3.0
#
#     Total Spent Payment Method  Location Transaction Date Discount Applied
# 21        105.0    Credit Card  In-store       2023-10-29              NaN

# %%
df.loc[m_3.index,"Item"]="Item_21_MILK"

# %%
m_4=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
m_4
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[m_4.index,"Item"]="Item_5_MILK"

# %%
m_5=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
m_5
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[m_5.index,"Item"]="Item_20_MILK"

# %%
m_6=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
m_6
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[m_6.index,"Item"]="Item_7_MILK"

# %%
m_7=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
m_7
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 472      TXN_9917843     CUST_11  Milk Products  NaN             9.5
# 4527     TXN_1772473     CUST_02  Milk Products  NaN             9.5
# 10633    TXN_8342635     CUST_24  Milk Products  NaN             9.5
# 11888    TXN_4995249     CUST_14  Milk Products  NaN             9.5
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 472        10.0         95.0  Digital Wallet    Online       2024-03-04
# 4527        2.0         19.0     Credit Card    Online       2023-03-26
# 10633       2.0         19.0  Digital Wallet  In-store       2022-07-30
# 11888       3.0         28.5  Digital Wallet    Online       2022-07-28
#
#       Discount Applied
# 472               True
# 4527               NaN
# 10633            False
# 11888              NaN

# %%
df.loc[m_7.index,"Item"]="Item_4_MILK"

# %%
m_8=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==23.0) & (df["Item"].isnull())]
m_8
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 5050    TXN_4284755     CUST_07  Milk Products  NaN            23.0       4.0
# 5423    TXN_5534368     CUST_09  Milk Products  NaN            23.0       6.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 5050         92.0           Cash    Online       2024-10-13            False
# 5423        138.0    Credit Card  In-store       2022-04-14            False

# %%
df.loc[m_8.index,"Item"]="Item_13_MILK"

# %%
m_9=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
m_9
# Out:
#      Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 501     TXN_4298975     CUST_22  Milk Products  NaN            30.5       2.0
# 1921    TXN_2092827     CUST_25  Milk Products  NaN            30.5       1.0
# 3074    TXN_3748574     CUST_17  Milk Products  NaN            30.5       5.0
# 5694    TXN_2387612     CUST_08  Milk Products  NaN            30.5       5.0
#
#       Total Spent  Payment Method Location Transaction Date Discount Applied
# 501          61.0  Digital Wallet   Online       2023-12-18            False
# 1921         30.5  Digital Wallet   Online       2023-10-01            False
# 3074        152.5     Credit Card   Online       2022-03-30            False
# 5694        152.5     Credit Card   Online       2024-12-24            False

# %%
df.loc[m_9.index,"Item"]="Item_18_MILK"

# %%
m_10=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
m_10
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 5629     TXN_8101070     CUST_09  Milk Products  NaN            36.5
# 7571     TXN_8670643     CUST_11  Milk Products  NaN            36.5
# 7759     TXN_7806205     CUST_08  Milk Products  NaN            36.5
# 8446     TXN_3599137     CUST_19  Milk Products  NaN            36.5
# 11380    TXN_8616642     CUST_20  Milk Products  NaN            36.5
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 5629        9.0        328.5     Credit Card    Online       2024-01-26
# 7571        1.0         36.5  Digital Wallet    Online       2022-12-18
# 7759        3.0        109.5  Digital Wallet  In-store       2023-03-03
# 8446       10.0        365.0  Digital Wallet  In-store       2024-08-03
# 11380       4.0        146.0  Digital Wallet    Online       2023-11-06
#
#       Discount Applied
# 5629             False
# 7571             False
# 7759               NaN
# ...

# %%
df.loc[m_10.index,"Item"]="Item_22_MILK"

# %%
m_11=df[(df["Category"]=="Milk Products") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
m_11
# Out:
#       Transaction ID Customer ID       Category Item  Price Per Unit  \
# 10236    TXN_6002055     CUST_16  Milk Products  NaN            17.0
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 10236       1.0         17.0  Digital Wallet  In-store       2022-03-20
#
#       Discount Applied
# 10236             True

# %%
df.loc[m_11.index,"Item"]="Item_9_MILK"

# %%
df[(df["Item"].isnull())]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df[(df["Category"]=="Food") & (df["Item"].isnull())]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
fo_20=df[(df["Category"]=="Food") & (df["Price Per Unit"]== 5.0) & (df["Item"].isnull())]
fo_20
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 12258    TXN_9113838     CUST_24     Food  NaN             5.0       8.0
#
#        Total Spent Payment Method  Location Transaction Date Discount Applied
# 12258         40.0    Credit Card  In-store       2023-06-30             True

# %%
df.loc[fo_20.index,"Item"]="Item_1_food"

# %%
fo_19=df[(df["Category"]=="Food") & (df["Price Per Unit"]== 6.5) & (df["Item"].isnull())]
fo_19
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[fo_19.index,"Item"]="Item_2_food"

# %%
fo_18=df[(df["Category"]=="Food") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
fo_18
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[fo_18.index,"Item"]="Item_15_food"

# %%
fo_17=df[(df["Category"]=="Food") & (df["Price Per Unit"]== 9.5) & (df["Item"].isnull())]
fo_17
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[fo_17.index,"Item"]="Item_4_food"

# %%
fo_16=df[(df["Category"]=="Food") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
fo_16
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Category, Item, Price Per Unit, Quantity, Total Spent, Payment Method, Location, Transaction Date, Discount Applied]
# Index: []

# %%
df.loc[fo_16.index,"Item"]="Item_9_food"

# %%
fo_15=df[(df["Category"]=="Food") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
fo_15
# Out:
#      Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 3388    TXN_6702252     CUST_23     Food  NaN            30.5       4.0
# 5754    TXN_9580748     CUST_08     Food  NaN            30.5       5.0
# 8484    TXN_8036579     CUST_01     Food  NaN            30.5       2.0
#
#       Total Spent  Payment Method Location Transaction Date Discount Applied
# 3388        122.0  Digital Wallet   Online       2024-09-11            False
# 5754        152.5     Credit Card   Online       2023-06-28            False
# 8484         61.0  Digital Wallet   Online       2024-05-23             True

# %%
df.loc[fo_15.index,"Item"]="Item_18_FOOD"

# %%
fo_14=df[(df["Category"]=="Food") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
fo_14
# Out:
#      Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 1745    TXN_5690221     CUST_06     Food  NaN            36.5       1.0
# 7993    TXN_4848182     CUST_21     Food  NaN            36.5       4.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1745         36.5  Digital Wallet  In-store       2022-10-06             True
# 7993        146.0     Credit Card    Online       2023-09-11              NaN

# %%
df.loc[fo_14.index,"Item"]="Item_22_FOOD"

# %%
fo_13=df[(df["Category"]=="Food") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
fo_13
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 3836     TXN_4246606     CUST_02     Food  NaN            29.0       7.0
# 5832     TXN_4355077     CUST_24     Food  NaN            29.0       5.0
# 6519     TXN_3925839     CUST_05     Food  NaN            29.0       9.0
# 9945     TXN_9714585     CUST_07     Food  NaN            29.0      10.0
# 10843    TXN_1207984     CUST_17     Food  NaN            29.0       6.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3836         203.0     Credit Card    Online       2023-10-24            False
# 5832         145.0            Cash  In-store       2023-02-24              NaN
# 6519         261.0            Cash    Online       2024-04-03              NaN
# 9945         290.0  Digital Wallet    Online       2024-11-10              NaN
# 10843        174.0     Credit Card  In-store       2022-05-10              NaN

# %%
df.loc[fo_13.index,"Item"]="Item_17_FOOD"

# %%
fo_12=df[(df["Category"]=="Food") & (df["Price Per Unit"]==12.5) & (df["Item"].isnull())]
fo_12
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 3482     TXN_7984930     CUST_23     Food  NaN            12.5       9.0
# 7458     TXN_4989570     CUST_03     Food  NaN            12.5       7.0
# 8638     TXN_5647485     CUST_15     Food  NaN            12.5       9.0
# 8868     TXN_4123276     CUST_14     Food  NaN            12.5       5.0
# 10815    TXN_2205066     CUST_11     Food  NaN            12.5       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3482         112.5            Cash  In-store       2022-09-01             True
# 7458          87.5  Digital Wallet    Online       2023-08-23             True
# 8638         112.5  Digital Wallet  In-store       2024-01-13            False
# 8868          62.5  Digital Wallet    Online       2023-07-09            False
# 10815         25.0  Digital Wallet  In-store       2024-06-23             True

# %%
df.loc[fo_12.index,"Item"]="Item_6_FOOD"

# %%
fo_11=df[(df["Category"]=="Food") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
fo_11
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 2690     TXN_1432445     CUST_01     Food  NaN            20.0       9.0
# 5551     TXN_4681123     CUST_14     Food  NaN            20.0       4.0
# 7531     TXN_1322913     CUST_18     Food  NaN            20.0       4.0
# 8090     TXN_2618457     CUST_02     Food  NaN            20.0       6.0
# 9209     TXN_3875311     CUST_13     Food  NaN            20.0       2.0
# 12313    TXN_3525275     CUST_21     Food  NaN            20.0       1.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2690         180.0            Cash  In-store       2023-08-01              NaN
# 5551          80.0     Credit Card    Online       2024-11-30            False
# 7531          80.0  Digital Wallet    Online       2022-09-20             True
# 8090         120.0     Credit Card  In-store       2022-07-11             True
# ...

# %%
df.loc[fo_11.index,"Item"]="Item_11_FOOD"

# %%
fo_10=df[(df["Category"]=="Food") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
fo_10
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 2450     TXN_4383900     CUST_23     Food  NaN            41.0       1.0
# 4294     TXN_6663420     CUST_21     Food  NaN            41.0       7.0
# 5247     TXN_2765031     CUST_17     Food  NaN            41.0       5.0
# 6405     TXN_6027222     CUST_18     Food  NaN            41.0       2.0
# 6937     TXN_5628367     CUST_04     Food  NaN            41.0       3.0
# 8596     TXN_2288041     CUST_24     Food  NaN            41.0      10.0
# 11601    TXN_5943276     CUST_02     Food  NaN            41.0       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2450          41.0            Cash    Online       2024-07-23             True
# 4294         287.0     Credit Card  In-store       2023-06-12             True
# 5247         205.0  Digital Wallet    Online       2024-11-08             True
# ...

# %%
df.loc[fo_10.index,"Item"]="Item_25_FOOD"

# %%
fo_9=df[(df["Category"]=="Food") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
fo_9
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 3569     TXN_9648976     CUST_09     Food  NaN            33.5       9.0
# 4250     TXN_6034757     CUST_07     Food  NaN            33.5       7.0
# 6829     TXN_7747407     CUST_08     Food  NaN            33.5       6.0
# 8117     TXN_4822005     CUST_10     Food  NaN            33.5       8.0
# 12511    TXN_5715500     CUST_17     Food  NaN            33.5       3.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3569         301.5            Cash  In-store       2024-09-26            False
# 4250         234.5            Cash  In-store       2023-09-27            False
# 6829         201.0            Cash    Online       2024-04-09            False
# 8117         268.0     Credit Card    Online       2023-02-26              NaN
# 12511        100.5  Digital Wallet    Online       2024-06-05            False

# %%
df.loc[fo_9.index,"Item"]="Item_20_FOOD"

# %%
fo_8=df[(df["Category"]=="Food") & (df["Price Per Unit"]==8.0) & (df["Item"].isnull())]
fo_8
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 2220     TXN_6609828     CUST_07     Food  NaN             8.0       5.0
# 4228     TXN_8890563     CUST_03     Food  NaN             8.0      10.0
# 8698     TXN_2010228     CUST_17     Food  NaN             8.0       4.0
# 9756     TXN_2602356     CUST_12     Food  NaN             8.0       5.0
# 10365    TXN_3935581     CUST_07     Food  NaN             8.0      10.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2220          40.0     Credit Card    Online       2022-04-06              NaN
# 4228          80.0     Credit Card    Online       2022-05-26            False
# 8698          32.0  Digital Wallet  In-store       2025-01-06              NaN
# 9756          40.0            Cash    Online       2024-01-31              NaN
# 10365         80.0  Digital Wallet  In-store       2024-05-13             True

# %%
df.loc[fo_8.index,"Item"]="Item_3_FOOD"

# %%
fo_7=df[(df["Category"]=="Food") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
fo_7
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 956      TXN_9017628     CUST_19     Food  NaN            11.0       5.0
# 1315     TXN_1792761     CUST_11     Food  NaN            11.0       7.0
# 2521     TXN_5518537     CUST_19     Food  NaN            11.0       1.0
# 5514     TXN_3119110     CUST_22     Food  NaN            11.0       8.0
# 7554     TXN_5442078     CUST_08     Food  NaN            11.0       7.0
# 12151    TXN_3760030     CUST_05     Food  NaN            11.0       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 956           55.0     Credit Card  In-store       2022-10-10            False
# 1315          77.0  Digital Wallet    Online       2022-01-26              NaN
# 2521          11.0            Cash  In-store       2023-02-08              NaN
# 5514          88.0            Cash    Online       2024-04-30            False
# ...

# %%
df.loc[fo_7.index,"Item"]="Item_5_FOOD"

# %%
fo_6=df[(df["Category"]=="Food") & (df["Price Per Unit"]==21.5) & (df["Item"].isnull())]
fo_6
# Out:
#      Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 460     TXN_4897743     CUST_01     Food  NaN            21.5       9.0
# 3202    TXN_7982451     CUST_22     Food  NaN            21.5       8.0
# 4126    TXN_5017130     CUST_08     Food  NaN            21.5       5.0
# 9238    TXN_6842211     CUST_22     Food  NaN            21.5       9.0
# 9846    TXN_1032287     CUST_16     Food  NaN            21.5       2.0
# 9870    TXN_7868771     CUST_14     Food  NaN            21.5       5.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 460         193.5     Credit Card  In-store       2024-03-18              NaN
# 3202        172.0  Digital Wallet    Online       2023-10-18             True
# 4126        107.5     Credit Card  In-store       2024-04-01            False
# 9238        193.5  Digital Wallet    Online       2024-08-16            False
# ...

# %%
df.loc[fo_6.index,"Item"]="Item_12_FOOD"

# %%
fo_5=df[(df["Category"]=="Food") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
fo_5
# Out:
#      Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 6564    TXN_5612175     CUST_03     Food  NaN            35.0       2.0
# 6984    TXN_3648215     CUST_01     Food  NaN            35.0       6.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 6564         70.0           Cash    Online       2025-01-16             True
# 6984        210.0           Cash  In-store       2024-03-29              NaN

# %%
df.loc[fo_5.index,"Item"]="Item_21_FOOD"

# %%
fo_4=df[(df["Category"]=="Food") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
fo_4
# Out:
#      Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 9572    TXN_6345102     CUST_23     Food  NaN            27.5       6.0
#
#       Total Spent Payment Method Location Transaction Date Discount Applied
# 9572        165.0           Cash   Online       2022-12-20              NaN

# %%
df.loc[fo_4.index,"Item"]="Item_16_FOOD"

# %%
fo_1=df[(df["Category"]=="Food") & (df["Price Per Unit"]==24.5) & (df["Item"].isnull())]
fo_1
# Out:
#       Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 32       TXN_1543244     CUST_20     Food  NaN            24.5       8.0
# 3401     TXN_6600756     CUST_18     Food  NaN            24.5       7.0
# 3979     TXN_8699307     CUST_09     Food  NaN            24.5      10.0
# 5445     TXN_1991377     CUST_16     Food  NaN            24.5       7.0
# 6020     TXN_9418439     CUST_23     Food  NaN            24.5       5.0
# 8501     TXN_3329144     CUST_23     Food  NaN            24.5       3.0
# 8897     TXN_5758502     CUST_21     Food  NaN            24.5       3.0
# 10119    TXN_3427189     CUST_09     Food  NaN            24.5       9.0
# 10261    TXN_7179907     CUST_22     Food  NaN            24.5      10.0
#
#        Total Spent Payment Method  Location Transaction Date Discount Applied
# 32           196.0    Credit Card    Online       2024-10-25             True
# 3401         171.5           Cash  In-store       2023-05-19              NaN
# ...

# %%
df.loc[fo_1.index,"Item"]="Item_14_FOOD"

# %%
fo_2=df[(df["Category"]=="Food") & (df["Price Per Unit"]==23.0) & (df["Item"].isnull())]
fo_2
# Out:
#      Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 443     TXN_5361643     CUST_19     Food  NaN            23.0       2.0
# 852     TXN_8624505     CUST_19     Food  NaN            23.0       9.0
# 950     TXN_1096977     CUST_07     Food  NaN            23.0       9.0
# 1317    TXN_6103372     CUST_23     Food  NaN            23.0       3.0
# 2029    TXN_2232017     CUST_11     Food  NaN            23.0       8.0
# 8003    TXN_9361358     CUST_13     Food  NaN            23.0       5.0
# 8160    TXN_9302123     CUST_04     Food  NaN            23.0       3.0
# 8708    TXN_7156790     CUST_10     Food  NaN            23.0       4.0
# 8799    TXN_4793029     CUST_20     Food  NaN            23.0       4.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 443          46.0  Digital Wallet    Online       2023-12-19              NaN
# 852         207.0            Cash  In-store       2023-09-15             True
# ...

# %%
df.loc[fo_2.index,"Item"]="Item_13_FOOD"

# %%
fo_3=df[(df["Category"]=="Food") & (df["Price Per Unit"]==18.5) & (df["Item"].isnull())]
fo_3
# Out:
#     Transaction ID Customer ID Category Item  Price Per Unit  Quantity  \
# 461    TXN_1565398     CUST_25     Food  NaN            18.5       8.0
#
#      Total Spent Payment Method  Location Transaction Date Discount Applied
# 461        148.0    Credit Card  In-store       2022-06-15              NaN

# %%
df.loc[fo_3.index,"Item"]="Item_10_FOOD"

# %%
b_22=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
b_22
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 2951    TXN_6048384     CUST_07  Butchers  NaN            41.0       4.0
# 4532    TXN_6772439     CUST_23  Butchers  NaN            41.0       4.0
# 7242    TXN_7597821     CUST_01  Butchers  NaN            41.0       5.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 2951        164.0           Cash    Online       2022-05-19              NaN
# 4532        164.0           Cash    Online       2023-10-15            False
# 7242        205.0    Credit Card  In-store       2024-05-18             True

# %%
df.loc[b_22.index,"Item"]="Item_25_BUT"

# %%
b_21=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
b_21
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1907    TXN_1007496     CUST_01  Butchers  NaN            15.5      10.0
# 2597    TXN_3122781     CUST_09  Butchers  NaN            15.5       7.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1907        155.0     Credit Card    Online       2024-02-05             True
# 2597        108.5  Digital Wallet  In-store       2023-07-21              NaN

# %%
df.loc[b_21.index,"Item"]="Item_8_BUT"

# %%
b_20=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
b_20
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 3071    TXN_5807928     CUST_08  Butchers  NaN            20.0       9.0
# 9429    TXN_6730547     CUST_18  Butchers  NaN            20.0       2.0
#
#       Total Spent Payment Method Location Transaction Date Discount Applied
# 3071        180.0           Cash   Online       2024-11-08             True
# 9429         40.0    Credit Card   Online       2024-01-17             True

# %%
df.loc[b_20.index,"Item"]="Item_11_BUT"

# %%
b_19=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
b_19
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 4053    TXN_3434264     CUST_07  Butchers  NaN            33.5       5.0
# 4203    TXN_6834397     CUST_09  Butchers  NaN            33.5       9.0
# 5080    TXN_5863318     CUST_18  Butchers  NaN            33.5       3.0
# 9370    TXN_8373098     CUST_18  Butchers  NaN            33.5       7.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 4053        167.5  Digital Wallet    Online       2023-07-11              NaN
# 4203        301.5            Cash    Online       2022-09-29              NaN
# 5080        100.5  Digital Wallet  In-store       2022-04-09            False
# 9370        234.5  Digital Wallet    Online       2024-04-02              NaN

# %%
df.loc[b_19.index,"Item"]="Item_20_BUT"

# %%
b_18=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==8.0) & (df["Item"].isnull())]
b_18
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 965      TXN_7109246     CUST_04  Butchers  NaN             8.0       8.0
# 4505     TXN_6530143     CUST_17  Butchers  NaN             8.0       6.0
# 8884     TXN_9611416     CUST_19  Butchers  NaN             8.0       3.0
# 9471     TXN_7302842     CUST_15  Butchers  NaN             8.0      10.0
# 10070    TXN_8332438     CUST_12  Butchers  NaN             8.0       2.0
#
#        Total Spent  Payment Method Location Transaction Date Discount Applied
# 965           64.0            Cash   Online       2022-03-11            False
# 4505          48.0  Digital Wallet   Online       2023-10-12              NaN
# 8884          24.0  Digital Wallet   Online       2022-09-02             True
# 9471          80.0  Digital Wallet   Online       2024-11-05              NaN
# 10070         16.0     Credit Card   Online       2024-04-19             True

# %%
df.loc[b_18.index,"Item"]="Item_3_BUT"

# %%
b_17=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==5.0) & (df["Item"].isnull())]
b_17
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 4888     TXN_1563614     CUST_11  Butchers  NaN             5.0       5.0
# 7392     TXN_3971163     CUST_17  Butchers  NaN             5.0       9.0
# 12242    TXN_5495445     CUST_21  Butchers  NaN             5.0       7.0
#
#        Total Spent  Payment Method Location Transaction Date Discount Applied
# 4888          25.0     Credit Card   Online       2022-01-13             True
# 7392          45.0  Digital Wallet   Online       2022-07-29             True
# 12242         35.0            Cash   Online       2023-09-18              NaN

# %%
df.loc[b_17.index,"Item"]="Item_1_BUT"

# %%
b_16=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==24.5) & (df["Item"].isnull())]
b_16
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 7780     TXN_9649004     CUST_11  Butchers  NaN            24.5       2.0
# 11965    TXN_7714982     CUST_20  Butchers  NaN            24.5       4.0
#
#        Total Spent Payment Method Location Transaction Date Discount Applied
# 7780          49.0           Cash   Online       2022-07-16              NaN
# 11965         98.0    Credit Card   Online       2024-06-17             True

# %%
df.loc[b_16.index,"Item"]="Item_14_BUT"

# %%
b_15=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
b_15
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1731     TXN_8023340     CUST_14  Butchers  NaN            36.5       8.0
# 3758     TXN_6842216     CUST_10  Butchers  NaN            36.5       6.0
# 5162     TXN_4288227     CUST_08  Butchers  NaN            36.5       8.0
# 6323     TXN_8364453     CUST_08  Butchers  NaN            36.5       3.0
# 6845     TXN_5026398     CUST_25  Butchers  NaN            36.5       9.0
# 7393     TXN_7877933     CUST_15  Butchers  NaN            36.5       2.0
# 9236     TXN_3873648     CUST_12  Butchers  NaN            36.5       4.0
# 10556    TXN_9122442     CUST_10  Butchers  NaN            36.5       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1731         292.0            Cash    Online       2023-10-04             True
# 3758         219.0            Cash    Online       2022-01-25            False
# ...

# %%
df.loc[b_15.index,"Item"]="Item_22_BUT"

# %%
b_14=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
b_14
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1179    TXN_2897310     CUST_19  Butchers  NaN            29.0       9.0
# 9830    TXN_3526562     CUST_24  Butchers  NaN            29.0       1.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1179        261.0  Digital Wallet  In-store       2023-06-25            False
# 9830         29.0     Credit Card    Online       2024-10-27             True

# %%
df.loc[b_14.index,"Item"]="Item_17_BUT"

# %%
b_13=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
b_13
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1319     TXN_4417302     CUST_11  Butchers  NaN            26.0       9.0
# 2232     TXN_8006993     CUST_05  Butchers  NaN            26.0       6.0
# 3461     TXN_5789870     CUST_23  Butchers  NaN            26.0       6.0
# 10594    TXN_7194672     CUST_18  Butchers  NaN            26.0       8.0
# 12491    TXN_7894525     CUST_23  Butchers  NaN            26.0       1.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1319         234.0     Credit Card    Online       2024-09-05            False
# 2232         156.0  Digital Wallet  In-store       2024-09-13             True
# 3461         156.0     Credit Card  In-store       2023-11-23            False
# 10594        208.0  Digital Wallet    Online       2024-10-07             True
# 12491         26.0     Credit Card    Online       2023-01-31             True

# %%
df.loc[b_13.index,"Item"]="Item_15_BUT"

# %%
b_12=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==39.5) & (df["Item"].isnull())]
b_12
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1009    TXN_2090456     CUST_05  Butchers  NaN            39.5      10.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 1009        395.0           Cash  In-store       2023-12-15             True

# %%
df.loc[b_12.index,"Item"]="Item_24_BUT"

# %%
b_11=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==12.5) & (df["Item"].isnull())]
b_11
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1453    TXN_7349203     CUST_13  Butchers  NaN            12.5       9.0
# 9459    TXN_9416158     CUST_24  Butchers  NaN            12.5       2.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 1453        112.5           Cash  In-store       2024-03-08             True
# 9459         25.0           Cash  In-store       2023-01-27            False

# %%
df.loc[b_11.index,"Item"]="Item_6_BUT"

# %%
b_1=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==38.0) & (df["Item"].isnull())]
b_1
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 668      TXN_5476798     CUST_02  Butchers  NaN            38.0      10.0
# 1259     TXN_3784837     CUST_16  Butchers  NaN            38.0       1.0
# 3220     TXN_2904039     CUST_22  Butchers  NaN            38.0       4.0
# 6424     TXN_4379762     CUST_17  Butchers  NaN            38.0       6.0
# 8722     TXN_1702959     CUST_03  Butchers  NaN            38.0      10.0
# 11411    TXN_2032489     CUST_14  Butchers  NaN            38.0       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 668          380.0  Digital Wallet    Online       2022-10-07            False
# 1259          38.0     Credit Card    Online       2024-06-06            False
# 3220         152.0     Credit Card    Online       2023-08-11              NaN
# 6424         228.0     Credit Card    Online       2024-08-06             True
# ...

# %%
df.loc[b_1.index,"Item"]="Item_23_BUT"

# %%
b_2=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
b_2
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 127     TXN_4608122     CUST_21  Butchers  NaN            27.5      10.0
# 2265    TXN_3661483     CUST_02  Butchers  NaN            27.5       4.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 127         275.0  Digital Wallet    Online       2022-10-01            False
# 2265        110.0            Cash  In-store       2022-01-20              NaN

# %%
df.loc[b_2.index,"Item"]="Item_16_BUT"

# %%
b_3=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==23.0) & (df["Item"].isnull())]
b_3
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 892      TXN_8905154     CUST_09  Butchers  NaN            23.0       5.0
# 1680     TXN_9315594     CUST_25  Butchers  NaN            23.0       2.0
# 4705     TXN_4761736     CUST_12  Butchers  NaN            23.0       4.0
# 5397     TXN_9799191     CUST_11  Butchers  NaN            23.0       9.0
# 6257     TXN_4130110     CUST_20  Butchers  NaN            23.0       4.0
# 6846     TXN_7565406     CUST_15  Butchers  NaN            23.0       9.0
# 9100     TXN_4335485     CUST_25  Butchers  NaN            23.0       5.0
# 10597    TXN_6725698     CUST_06  Butchers  NaN            23.0       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 892          115.0     Credit Card  In-store       2022-10-24              NaN
# 1680          46.0     Credit Card  In-store       2024-07-22            False
# ...

# %%
df.loc[b_3.index,"Item"]="Item_13_BUT"

# %%
b_4=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
b_4
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 537     TXN_6586324     CUST_15  Butchers  NaN            30.5       6.0
# 3318    TXN_8087160     CUST_08  Butchers  NaN            30.5       5.0
# 6682    TXN_1813718     CUST_03  Butchers  NaN            30.5       1.0
# 9135    TXN_8240954     CUST_24  Butchers  NaN            30.5       3.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 537         183.0  Digital Wallet  In-store       2024-05-08              NaN
# 3318        152.5            Cash    Online       2024-01-26              NaN
# 6682         30.5     Credit Card  In-store       2023-06-08              NaN
# 9135         91.5            Cash    Online       2022-04-05            False

# %%
df.loc[b_4.index,"Item"]="Item_18_BUT"

# %%
b_5=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
b_5
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 159     TXN_3822751     CUST_21  Butchers  NaN            14.0       9.0
# 1642    TXN_3745950     CUST_11  Butchers  NaN            14.0       7.0
# 4586    TXN_6566133     CUST_04  Butchers  NaN            14.0       9.0
# 9553    TXN_9805058     CUST_19  Butchers  NaN            14.0       7.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 159         126.0  Digital Wallet  In-store       2024-03-04            False
# 1642         98.0  Digital Wallet  In-store       2022-08-08             True
# 4586        126.0     Credit Card  In-store       2022-07-27             True
# 9553         98.0            Cash  In-store       2024-06-24              NaN

# %%
df.loc[b_5.index,"Item"]="Item_7_BUT"

# %%
b_6=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
b_6
# Out:
#     Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 920    TXN_2031813     CUST_12  Butchers  NaN             6.5       1.0
#
#      Total Spent Payment Method Location Transaction Date Discount Applied
# 920          6.5    Credit Card   Online       2024-07-11             True

# %%
df.loc[b_6.index,"Item"]="Item_2_BUT"

# %%
b_7=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
b_7
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 2884    TXN_8947708     CUST_04  Butchers  NaN            11.0       2.0
# 5654    TXN_4429872     CUST_03  Butchers  NaN            11.0      10.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 2884         22.0           Cash  In-store       2023-03-20              NaN
# 5654        110.0    Credit Card  In-store       2024-01-27             True

# %%
df.loc[b_7.index,"Item"]="Item_5_BUT"

# %%
b_8=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
b_8
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 1085    TXN_5006011     CUST_10  Butchers  NaN            35.0       8.0
# 4348    TXN_2201759     CUST_15  Butchers  NaN            35.0       2.0
# 4479    TXN_6383890     CUST_10  Butchers  NaN            35.0       3.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 1085        280.0           Cash  In-store       2022-01-11              NaN
# 4348         70.0           Cash  In-store       2023-11-15              NaN
# 4479        105.0    Credit Card    Online       2023-07-26             True

# %%
df.loc[b_8.index,"Item"]="Item_21_BUT"

# %%
b_9=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
b_9
# Out:
#      Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 9609    TXN_8831425     CUST_12  Butchers  NaN             9.5       3.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 9609         28.5    Credit Card  In-store       2023-09-08             True

# %%
df.loc[b_9.index,"Item"]="Item_4_BUT"

# %%
b_10=df[(df["Category"]=="Butchers") & (df["Price Per Unit"]==21.5) & (df["Item"].isnull())]
b_10
# Out:
#       Transaction ID Customer ID  Category Item  Price Per Unit  Quantity  \
# 966      TXN_5616762     CUST_04  Butchers  NaN            21.5       8.0
# 4973     TXN_9938912     CUST_07  Butchers  NaN            21.5       1.0
# 8344     TXN_5395629     CUST_14  Butchers  NaN            21.5       7.0
# 10068    TXN_7003816     CUST_10  Butchers  NaN            21.5       1.0
# 12198    TXN_4457696     CUST_22  Butchers  NaN            21.5      10.0
#
#        Total Spent Payment Method  Location Transaction Date Discount Applied
# 966          172.0    Credit Card    Online       2022-01-24             True
# 4973          21.5           Cash    Online       2023-07-23            False
# 8344         150.5    Credit Card    Online       2022-08-24             True
# 10068         21.5    Credit Card  In-store       2024-07-15              NaN
# 12198        215.0    Credit Card  In-store       2022-12-04             True

# %%
df.loc[b_10.index,"Item"]="Item_12_BUT"

# %%
df[(df["Category"]=="Electric household essentials") & (df["Item"].isnull())]
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 247      TXN_3433195     CUST_24  Electric household essentials  NaN
# 389      TXN_8348586     CUST_03  Electric household essentials  NaN
# 526      TXN_1285469     CUST_20  Electric household essentials  NaN
# 1191     TXN_1871707     CUST_10  Electric household essentials  NaN
# 1408     TXN_7470621     CUST_02  Electric household essentials  NaN
# ...              ...         ...                            ...  ...
# 12124    TXN_8951116     CUST_07  Electric household essentials  NaN
# 12299    TXN_7671253     CUST_12  Electric household essentials  NaN
# 12339    TXN_5105838     CUST_17  Electric household essentials  NaN
# 12365    TXN_2634754     CUST_07  Electric household essentials  NaN
# 12457    TXN_1352194     CUST_17  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# ...

# %%
e_21=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
e_21
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 2326    TXN_4205609     CUST_16  Electric household essentials  NaN
# 7012    TXN_7138571     CUST_13  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2326            35.0       8.0        280.0  Digital Wallet  In-store
# 7012            35.0       4.0        140.0            Cash    Online
#
#      Transaction Date Discount Applied
# 2326       2022-01-28              NaN
# 7012       2023-09-25            False

# %%
df.loc[e_21.index,"Item"]="Item_21_EHE"

# %%
e_20=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
e_20
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 2116    TXN_1505937     CUST_06  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 2116            29.0       1.0         29.0  Digital Wallet   Online
#
#      Transaction Date Discount Applied
# 2116       2023-06-04            False

# %%
df.loc[e_20.index,"Item"]="Item_17_EHE"

# %%
e_19=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==38.0) & (df["Item"].isnull())]
e_19
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 2227     TXN_9099328     CUST_12  Electric household essentials  NaN
# 2719     TXN_9291336     CUST_19  Electric household essentials  NaN
# 5623     TXN_3782741     CUST_15  Electric household essentials  NaN
# 8365     TXN_4275306     CUST_23  Electric household essentials  NaN
# 10234    TXN_3915802     CUST_04  Electric household essentials  NaN
# 10297    TXN_5452486     CUST_13  Electric household essentials  NaN
# 11047    TXN_8685497     CUST_13  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2227             38.0      10.0        380.0  Digital Wallet  In-store
# 2719             38.0      10.0        380.0  Digital Wallet  In-store
# 5623             38.0       4.0        152.0  Digital Wallet  In-store
# 8365             38.0       9.0        342.0  Digital Wallet  In-store
# ...

# %%
df.loc[e_19.index,"Item"]="Item_23_EHE"

# %%
e_18=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
e_18
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 9266     TXN_9864135     CUST_25  Electric household essentials  NaN
# 11556    TXN_9815869     CUST_17  Electric household essentials  NaN
# 11906    TXN_9958675     CUST_24  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 9266             20.0       1.0         20.0  Digital Wallet    Online
# 11556            20.0       9.0        180.0     Credit Card  In-store
# 11906            20.0       6.0        120.0            Cash  In-store
#
#       Transaction Date Discount Applied
# 9266        2023-08-17            False
# 11556       2022-06-25              NaN
# 11906       2024-02-27              NaN

# %%
df.loc[e_18.index,"Item"]="Item_11_EHE"

# %%
e_17=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
e_17
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 2311    TXN_1137542     CUST_21  Electric household essentials  NaN
# 3928    TXN_2306040     CUST_08  Electric household essentials  NaN
# 6226    TXN_2168603     CUST_16  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2311            11.0       1.0         11.0     Credit Card  In-store
# 3928            11.0       8.0         88.0            Cash    Online
# 6226            11.0       2.0         22.0  Digital Wallet  In-store
#
#      Transaction Date Discount Applied
# 2311       2023-06-29              NaN
# 3928       2023-11-27             True
# 6226       2023-07-23             True

# %%
df.loc[e_17.index,"Item"]="Item_5_EHE"

# %%
e_16=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==18.5) & (df["Item"].isnull())]
e_16
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 3470    TXN_8171410     CUST_18  Electric household essentials  NaN
# 8653    TXN_1610493     CUST_11  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 3470            18.5       8.0        148.0  Digital Wallet  In-store
# 8653            18.5       1.0         18.5            Cash    Online
#
#      Transaction Date Discount Applied
# 3470       2023-12-21            False
# 8653       2023-01-26              NaN

# %%
df.loc[e_16.index,"Item"]="Item_10_EHE"

# %%
e_15=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==32.0) & (df["Item"].isnull())]
e_15
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 3227    TXN_2522970     CUST_18  Electric household essentials  NaN
# 5018    TXN_8823017     CUST_06  Electric household essentials  NaN
# 8659    TXN_4452577     CUST_16  Electric household essentials  NaN
# 8810    TXN_3922646     CUST_08  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 3227            32.0       6.0        192.0  Digital Wallet  In-store
# 5018            32.0      10.0        320.0  Digital Wallet    Online
# 8659            32.0       4.0        128.0  Digital Wallet    Online
# 8810            32.0       2.0         64.0            Cash    Online
#
#      Transaction Date Discount Applied
# 3227       2024-04-25            False
# 5018       2023-04-10              NaN
# 8659       2022-02-13             True
# 8810       2023-07-27            False

# %%
df.loc[e_15.index,"Item"]="Item_19_EHE"

# %%
e_14=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
e_14
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 5857    TXN_8683777     CUST_03  Electric household essentials  NaN
# 9898    TXN_6004811     CUST_18  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 5857            30.5       2.0         61.0  Digital Wallet    Online
# 9898            30.5       6.0        183.0  Digital Wallet  In-store
#
#      Transaction Date Discount Applied
# 5857       2023-07-05             True
# 9898       2023-07-08            False

# %%
df.loc[e_14.index,"Item"]="Item_18_EHE"

# %%
e_13=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
e_13
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 526     TXN_1285469     CUST_20  Electric household essentials  NaN
# 3956    TXN_7433742     CUST_12  Electric household essentials  NaN
# 4553    TXN_3841567     CUST_24  Electric household essentials  NaN
# 7250    TXN_1284380     CUST_06  Electric household essentials  NaN
# 9310    TXN_3666581     CUST_07  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 526             15.5       7.0        108.5  Digital Wallet    Online
# 3956            15.5       5.0         77.5  Digital Wallet    Online
# 4553            15.5       8.0        124.0            Cash  In-store
# 7250            15.5       4.0         62.0            Cash  In-store
# 9310            15.5       3.0         46.5            Cash  In-store
#
#      Transaction Date Discount Applied
# 526        2022-06-17            False
# 3956       2023-09-09             True
# ...

# %%
df.loc[e_13.index,"Item"]="Item_8_EHE"

# %%
e_12=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
e_12
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 3446    TXN_9438432     CUST_04  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 3446            17.0       2.0         34.0  Digital Wallet   Online
#
#      Transaction Date Discount Applied
# 3446       2024-06-26            False

# %%
df.loc[e_12.index,"Item"]="Item_9_EHE"

# %%
e_11=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
e_11
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 1651     TXN_4046056     CUST_09  Electric household essentials  NaN
# 2292     TXN_9551621     CUST_16  Electric household essentials  NaN
# 3929     TXN_7924859     CUST_12  Electric household essentials  NaN
# 6337     TXN_2894776     CUST_14  Electric household essentials  NaN
# 7924     TXN_6437047     CUST_03  Electric household essentials  NaN
# 10231    TXN_4047279     CUST_09  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 1651             36.5       5.0        182.5     Credit Card  In-store
# 2292             36.5       4.0        146.0     Credit Card  In-store
# 3929             36.5       3.0        109.5  Digital Wallet  In-store
# 6337             36.5       3.0        109.5            Cash  In-store
# 7924             36.5       7.0        255.5            Cash    Online
# ...

# %%
df.loc[e_11.index,"Item"]="Item_22_EHE"

# %%
e_10=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==12.5) & (df["Item"].isnull())]
e_10
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 6202     TXN_6462918     CUST_07  Electric household essentials  NaN
# 6324     TXN_5596069     CUST_08  Electric household essentials  NaN
# 11236    TXN_8830578     CUST_18  Electric household essentials  NaN
# 11311    TXN_4770477     CUST_24  Electric household essentials  NaN
# 12124    TXN_8951116     CUST_07  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 6202             12.5       7.0         87.5  Digital Wallet  In-store
# 6324             12.5       6.0         75.0            Cash    Online
# 11236            12.5       9.0        112.5            Cash    Online
# 11311            12.5       7.0         87.5  Digital Wallet    Online
# 12124            12.5       4.0         50.0     Credit Card    Online
#
#       Transaction Date Discount Applied
# 6202        2024-04-15             True
# 6324        2024-06-04            False
# ...

# %%
df.loc[e_10.index,"Item"]="Item_6_EHE"

# %%
e_9=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]    
e_9
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 1191     TXN_1871707     CUST_10  Electric household essentials  NaN
# 1408     TXN_7470621     CUST_02  Electric household essentials  NaN
# 6029     TXN_6862565     CUST_19  Electric household essentials  NaN
# 6253     TXN_6381262     CUST_05  Electric household essentials  NaN
# 7233     TXN_6866951     CUST_04  Electric household essentials  NaN
# 9231     TXN_2487307     CUST_19  Electric household essentials  NaN
# 11185    TXN_4786582     CUST_16  Electric household essentials  NaN
# 11595    TXN_8438783     CUST_04  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 1191             33.5       1.0         33.5  Digital Wallet  In-store
# 1408             33.5       3.0        100.5            Cash    Online
# 6029             33.5       2.0         67.0  Digital Wallet    Online
# ...

# %%
df.loc[e_9.index,"Item"]="Item_20_EHE"

# %%
e_8=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
e_8
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 389     TXN_8348586     CUST_03  Electric household essentials  NaN
# 7070    TXN_4624810     CUST_20  Electric household essentials  NaN
# 7327    TXN_3978048     CUST_24  Electric household essentials  NaN
# 9632    TXN_2770070     CUST_22  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 389             27.5       8.0        220.0     Credit Card    Online
# 7070            27.5       9.0        247.5  Digital Wallet    Online
# 7327            27.5       2.0         55.0     Credit Card    Online
# 9632            27.5       6.0        165.0  Digital Wallet  In-store
#
#      Transaction Date Discount Applied
# 389        2022-08-12              NaN
# 7070       2023-11-08            False
# 7327       2024-04-26             True
# 9632       2022-06-10              NaN

# %%
df.loc[e_8.index,"Item"]="Item_16_EHE"

# %%
e_7=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==23.0) & (df["Item"].isnull())]
e_7
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 3583     TXN_9835299     CUST_04  Electric household essentials  NaN
# 5845     TXN_7583357     CUST_01  Electric household essentials  NaN
# 6715     TXN_3923033     CUST_05  Electric household essentials  NaN
# 6815     TXN_2953972     CUST_15  Electric household essentials  NaN
# 8232     TXN_9053395     CUST_11  Electric household essentials  NaN
# 12299    TXN_7671253     CUST_12  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 3583             23.0       2.0         46.0  Digital Wallet  In-store
# 5845             23.0       4.0         92.0  Digital Wallet    Online
# 6715             23.0       9.0        207.0     Credit Card    Online
# 6815             23.0       2.0         46.0  Digital Wallet    Online
# 8232             23.0      10.0        230.0  Digital Wallet    Online
# ...

# %%
df.loc[e_7.index,"Item"]="Item_13_EHE"

# %%
e_6=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
e_6
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 6468     TXN_9014397     CUST_19  Electric household essentials  NaN
# 12365    TXN_2634754     CUST_07  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent Payment Method Location  \
# 6468             26.0       3.0         78.0    Credit Card   Online
# 12365            26.0       3.0         78.0           Cash   Online
#
#       Transaction Date Discount Applied
# 6468        2022-04-22             True
# 12365       2022-05-15             True

# %%
df.loc[e_6.index,"Item"]="Item_15_EHE"

# %%
e_5=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
e_5
# Out:
#      Transaction ID Customer ID                       Category Item  \
# 9373    TXN_6948452     CUST_18  Electric household essentials  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 9373             9.5       5.0         47.5  Digital Wallet  In-store
#
#      Transaction Date Discount Applied
# 9373       2024-11-05              NaN

# %%
df.loc[e_5.index,"Item"]="Item_4_EHE"

# %%
e_4=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
e_4
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 11080    TXN_9811351     CUST_07  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 11080             6.5       6.0         39.0  Digital Wallet  In-store
#
#       Transaction Date Discount Applied
# 11080       2023-05-22            False

# %%
df.loc[e_4.index,"Item"]="Item_2_EHE"

# %%
e_1=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
e_1
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 5731     TXN_4317033     CUST_06  Electric household essentials  NaN
# 5781     TXN_5475355     CUST_02  Electric household essentials  NaN
# 5782     TXN_3681383     CUST_04  Electric household essentials  NaN
# 8508     TXN_4771109     CUST_21  Electric household essentials  NaN
# 8661     TXN_8016362     CUST_03  Electric household essentials  NaN
# 8786     TXN_4872092     CUST_23  Electric household essentials  NaN
# 10078    TXN_4327045     CUST_08  Electric household essentials  NaN
# 11056    TXN_5456972     CUST_16  Electric household essentials  NaN
# 11434    TXN_9404791     CUST_05  Electric household essentials  NaN
# 12339    TXN_5105838     CUST_17  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 5731             41.0       6.0        246.0  Digital Wallet  In-store
# ...

# %%
df.loc[e_1.index,"Item"]="Item_25_EHE"

# %%
e_2=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
e_2
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 7869     TXN_1044590     CUST_12  Electric household essentials  NaN
# 10427    TXN_1202968     CUST_11  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 7869             14.0       4.0         56.0            Cash   Online
# 10427            14.0       8.0        112.0  Digital Wallet   Online
#
#       Transaction Date Discount Applied
# 7869        2024-05-07            False
# 10427       2022-09-03             True

# %%
df.loc[e_2.index,"Item"]="Item_7_EHE"

# %%
e_3=df[(df["Category"]=="Electric household essentials") & (df["Price Per Unit"]==21.5) & (df["Item"].isnull())]
e_3
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 247      TXN_3433195     CUST_24  Electric household essentials  NaN
# 3611     TXN_3435432     CUST_14  Electric household essentials  NaN
# 8286     TXN_9887558     CUST_13  Electric household essentials  NaN
# 12457    TXN_1352194     CUST_17  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 247              21.5       7.0        150.5            Cash   Online
# 3611             21.5       7.0        150.5  Digital Wallet   Online
# 8286             21.5       4.0         86.0  Digital Wallet   Online
# 12457            21.5       4.0         86.0     Credit Card   Online
#
#       Transaction Date Discount Applied
# 247         2023-03-30              NaN
# 3611        2022-07-14              NaN
# 8286        2022-03-17             True
# 12457       2023-02-26              NaN

# %%
df.loc[e_3.index,"Item"]="Item_12_EHE"

# %%
bs_19=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
bs_19
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 5946     TXN_5780655     CUST_11  Beverages  NaN            29.0       5.0
# 9753     TXN_9161445     CUST_11  Beverages  NaN            29.0       6.0
# 11024    TXN_7191353     CUST_08  Beverages  NaN            29.0      10.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 5946         145.0     Credit Card    Online       2024-11-12              NaN
# 9753         174.0            Cash  In-store       2023-11-03              NaN
# 11024        290.0  Digital Wallet  In-store       2024-01-19            False

# %%
df.loc[bs_19.index,"Item"]="Item_17_BEV"

# %%
bs_18=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==38.0) & (df["Item"].isnull())]
bs_18
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 10064    TXN_9925855     CUST_03  Beverages  NaN            38.0       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 10064        304.0  Digital Wallet  In-store       2024-10-02              NaN

# %%
df.loc[bs_18.index,"Item"]="Item_23_BEV"

# %%
bs_17=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
bs_17
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 10218    TXN_6659981     CUST_17  Beverages  NaN            17.0       9.0
# 10909    TXN_5541676     CUST_17  Beverages  NaN            17.0       9.0
# 11195    TXN_3846417     CUST_17  Beverages  NaN            17.0       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 10218        153.0     Credit Card    Online       2023-06-19             True
# 10909        153.0  Digital Wallet    Online       2024-03-20            False
# 11195         34.0            Cash  In-store       2024-03-30             True

# %%
df.loc[bs_17.index,"Item"]="Item_9_BEV"

# %%
bs_16=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==32.0) & (df["Item"].isnull())]
bs_16
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 8592     TXN_3169757     CUST_11  Beverages  NaN            32.0       7.0
# 10976    TXN_3907047     CUST_19  Beverages  NaN            32.0       2.0
# 11932    TXN_8362813     CUST_20  Beverages  NaN            32.0       5.0
#
#        Total Spent  Payment Method Location Transaction Date Discount Applied
# 8592         224.0  Digital Wallet   Online       2024-04-04            False
# 10976         64.0            Cash   Online       2022-01-27             True
# 11932        160.0            Cash   Online       2022-08-22              NaN

# %%
df.loc[bs_16.index,"Item"]="Item_19_BEV"

# %%
bs_15=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==24.5) & (df["Item"].isnull())]
bs_15
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 2828     TXN_9082199     CUST_09  Beverages  NaN            24.5       9.0
# 6657     TXN_1434329     CUST_10  Beverages  NaN            24.5       2.0
# 9494     TXN_5831445     CUST_17  Beverages  NaN            24.5       4.0
# 12023    TXN_7798925     CUST_08  Beverages  NaN            24.5       9.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2828         220.5  Digital Wallet  In-store       2024-09-02            False
# 6657          49.0     Credit Card  In-store       2024-08-19            False
# 9494          98.0            Cash  In-store       2023-10-31              NaN
# 12023        220.5            Cash  In-store       2023-03-21            False

# %%
df.loc[bs_15.index,"Item"]="Item_14_BEV"

# %%
bs_14=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
bs_14
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 1612     TXN_7978551     CUST_20  Beverages  NaN            35.0       9.0
# 3129     TXN_2848709     CUST_23  Beverages  NaN            35.0      10.0
# 8073     TXN_8573044     CUST_23  Beverages  NaN            35.0       8.0
# 11427    TXN_3192013     CUST_01  Beverages  NaN            35.0       9.0
# 11781    TXN_2892369     CUST_03  Beverages  NaN            35.0       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1612         315.0  Digital Wallet    Online       2023-02-12             True
# 3129         350.0     Credit Card    Online       2022-07-31              NaN
# 8073         280.0     Credit Card  In-store       2023-02-18            False
# 11427        315.0            Cash  In-store       2022-02-13             True
# 11781        280.0     Credit Card  In-store       2023-06-10            False

# %%
df.loc[bs_14.index,"Item"]="Item_21_BEV"

# %%
bs_13=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
bs_13
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 5702     TXN_8279458     CUST_01  Beverages  NaN            30.5       2.0
# 11171    TXN_6629897     CUST_11  Beverages  NaN            30.5       7.0
#
#        Total Spent Payment Method  Location Transaction Date Discount Applied
# 5702          61.0    Credit Card    Online       2022-07-03             True
# 11171        213.5    Credit Card  In-store       2024-03-05             True

# %%
df.loc[bs_13.index,"Item"]="Item_18_BEV"

# %%
bs_12=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
bs_12
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 3798    TXN_9896915     CUST_22  Beverages  NaN             6.5       7.0
# 5603    TXN_1095879     CUST_15  Beverages  NaN             6.5      10.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3798         45.5  Digital Wallet  In-store       2024-04-29            False
# 5603         65.0  Digital Wallet  In-store       2023-02-04             True

# %%
df.loc[bs_12.index,"Item"]="Item_2_BEV"

# %%
bs_11=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==5.0) & (df["Item"].isnull())]
bs_11
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 11812    TXN_9502131     CUST_12  Beverages  NaN             5.0       3.0
# 12330    TXN_3708702     CUST_11  Beverages  NaN             5.0       4.0
#
#        Total Spent Payment Method Location Transaction Date Discount Applied
# 11812         15.0    Credit Card   Online       2023-07-19             True
# 12330         20.0    Credit Card   Online       2022-08-24            False

# %%
df.loc[bs_11.index,"Item"]="Item_1_BEV"

# %%
bs_1=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==8.0) & (df["Item"].isnull())]
bs_1
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 280     TXN_9469962     CUST_08  Beverages  NaN             8.0       6.0
# 2504    TXN_6590458     CUST_21  Beverages  NaN             8.0       2.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 280          48.0           Cash    Online       2024-02-26            False
# 2504         16.0           Cash  In-store       2024-01-29             True

# %%
df.loc[bs_1.index,"Item"]="Item_3_BEV"

# %%
bs_2=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==21.5) & (df["Item"].isnull())]
bs_2
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 552     TXN_7555309     CUST_12  Beverages  NaN            21.5       5.0
# 4094    TXN_5944536     CUST_02  Beverages  NaN            21.5       9.0
# 5331    TXN_1505264     CUST_11  Beverages  NaN            21.5       4.0
# 5499    TXN_6197590     CUST_10  Beverages  NaN            21.5       7.0
# 5606    TXN_2201869     CUST_03  Beverages  NaN            21.5       9.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 552         107.5     Credit Card    Online       2022-07-15             True
# 4094        193.5     Credit Card  In-store       2024-04-02            False
# 5331         86.0            Cash  In-store       2024-01-30            False
# 5499        150.5     Credit Card    Online       2022-08-15             True
# 5606        193.5  Digital Wallet  In-store       2022-07-26             True

# %%
df.loc[bs_2.index,"Item"]="Item_12_BEV"

# %%
bs_3=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
bs_3
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 1134     TXN_6471352     CUST_17  Beverages  NaN            20.0       4.0
# 1563     TXN_2049510     CUST_20  Beverages  NaN            20.0       1.0
# 1789     TXN_8624218     CUST_16  Beverages  NaN            20.0       8.0
# 2514     TXN_2434339     CUST_01  Beverages  NaN            20.0       9.0
# 7167     TXN_7780561     CUST_06  Beverages  NaN            20.0       4.0
# 7930     TXN_3987229     CUST_25  Beverages  NaN            20.0       3.0
# 10018    TXN_2261622     CUST_02  Beverages  NaN            20.0       9.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1134          80.0            Cash    Online       2025-01-05            False
# 1563          20.0  Digital Wallet  In-store       2024-09-04            False
# 1789         160.0            Cash    Online       2022-08-03            False
# ...

# %%
df.loc[bs_3.index,"Item"]="Item_11_BEV"

# %%
bs_4=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
bs_4
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 569     TXN_7101302     CUST_16  Beverages  NaN            33.5       1.0
# 7082    TXN_7450879     CUST_01  Beverages  NaN            33.5       4.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 569          33.5           Cash  In-store       2024-10-24             True
# 7082        134.0    Credit Card  In-store       2024-03-29            False

# %%
df.loc[bs_4.index,"Item"]="Item_20_BEV"

# %%
bs_5=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==39.5) & (df["Item"].isnull())]
bs_5
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 1186    TXN_2949356     CUST_17  Beverages  NaN            39.5       8.0
# 4379    TXN_6508162     CUST_06  Beverages  NaN            39.5       2.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1186        316.0  Digital Wallet    Online       2022-08-01            False
# 4379         79.0     Credit Card  In-store       2024-05-08              NaN

# %%
df.loc[bs_5.index,"Item"]="Item_24_BEV"

# %%
bs_6=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
bs_6
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 6224     TXN_7117073     CUST_18  Beverages  NaN            15.5       6.0
# 7929     TXN_9427980     CUST_12  Beverages  NaN            15.5       8.0
# 9896     TXN_5391734     CUST_12  Beverages  NaN            15.5       3.0
# 10156    TXN_3728004     CUST_25  Beverages  NaN            15.5       3.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 6224          93.0  Digital Wallet    Online       2023-12-07             True
# 7929         124.0            Cash    Online       2023-06-22              NaN
# 9896          46.5  Digital Wallet    Online       2024-11-17              NaN
# 10156         46.5            Cash  In-store       2022-08-23              NaN

# %%
df.loc[bs_6.index,"Item"]="Item_8_BEV"

# %%
bs_7=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
bs_7
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 2703    TXN_3813656     CUST_02  Beverages  NaN            27.5       1.0
# 3270    TXN_5650070     CUST_21  Beverages  NaN            27.5       6.0
# 4929    TXN_2596013     CUST_17  Beverages  NaN            27.5       4.0
# 7301    TXN_9620521     CUST_14  Beverages  NaN            27.5       2.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2703         27.5     Credit Card  In-store       2022-09-01            False
# 3270        165.0            Cash  In-store       2022-07-11             True
# 4929        110.0  Digital Wallet    Online       2022-01-16              NaN
# 7301         55.0            Cash    Online       2022-07-19            False

# %%
df.loc[bs_7.index,"Item"]="Item_16_BEV"

# %%
bs_8=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
bs_8
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 1703     TXN_9569469     CUST_08  Beverages  NaN            41.0       8.0
# 3995     TXN_4517752     CUST_05  Beverages  NaN            41.0       6.0
# 7449     TXN_4467507     CUST_01  Beverages  NaN            41.0       2.0
# 7471     TXN_5203845     CUST_16  Beverages  NaN            41.0       7.0
# 11367    TXN_3798658     CUST_25  Beverages  NaN            41.0       9.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1703         328.0  Digital Wallet    Online       2024-02-12              NaN
# 3995         246.0  Digital Wallet  In-store       2022-07-21              NaN
# 7449          82.0     Credit Card    Online       2023-07-24             True
# 7471         287.0  Digital Wallet    Online       2022-11-15              NaN
# 11367        369.0            Cash    Online       2024-02-24              NaN

# %%
df.loc[bs_8.index,"Item"]="Item_25_BEV"

# %%
bs_9=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
bs_9
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 2957     TXN_9080551     CUST_21  Beverages  NaN            14.0       2.0
# 3581     TXN_1208768     CUST_24  Beverages  NaN            14.0       2.0
# 3980     TXN_1212399     CUST_05  Beverages  NaN            14.0       8.0
# 4630     TXN_9221528     CUST_22  Beverages  NaN            14.0       6.0
# 7686     TXN_4099276     CUST_17  Beverages  NaN            14.0       6.0
# 10233    TXN_4128346     CUST_14  Beverages  NaN            14.0       3.0
# 12213    TXN_2556431     CUST_04  Beverages  NaN            14.0       7.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2957          28.0  Digital Wallet    Online       2022-07-21            False
# 3581          28.0            Cash    Online       2023-02-28              NaN
# 3980         112.0  Digital Wallet    Online       2024-01-17             True
# ...

# %%
df.loc[bs_9.index,"Item"]="Item_7_BEV"

# %%
bs_10=df[(df["Category"]=="Beverages") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
bs_10
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 2336     TXN_4123109     CUST_24  Beverages  NaN             9.5       2.0
# 2937     TXN_1236974     CUST_01  Beverages  NaN             9.5       8.0
# 8441     TXN_5221911     CUST_09  Beverages  NaN             9.5       9.0
# 10036    TXN_9698787     CUST_09  Beverages  NaN             9.5       3.0
# 11942    TXN_1071762     CUST_19  Beverages  NaN             9.5       3.0
# 12009    TXN_3763280     CUST_20  Beverages  NaN             9.5       1.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2336          19.0  Digital Wallet  In-store       2025-01-12             True
# 2937          76.0            Cash    Online       2023-04-21            False
# 8441          85.5     Credit Card    Online       2023-07-09            False
# 10036         28.5            Cash    Online       2024-11-13            False
# ...

# %%
df.loc[bs_10.index,"Item"]="Item_4_BEV"

# %%
fu_21=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==24.5) & (df["Item"].isnull())]
fu_21
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 9877     TXN_1586746     CUST_01  Furniture  NaN            24.5       3.0
# 12163    TXN_6506416     CUST_02  Furniture  NaN            24.5       5.0
#
#        Total Spent Payment Method  Location Transaction Date Discount Applied
# 9877          73.5    Credit Card    Online       2022-08-06             True
# 12163        122.5           Cash  In-store       2024-07-24             True

# %%
df.loc[fu_21.index,"Item"]="Item_14_FUR"

# %%
fu_20=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
fu_20
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 9806    TXN_9860940     CUST_09  Furniture  NaN            36.5       9.0
#
#       Total Spent Payment Method Location Transaction Date Discount Applied
# 9806        328.5    Credit Card   Online       2024-06-11              NaN

# %%
df.loc[fu_20.index,"Item"]="Item_22_FUR"

# %%
fu_19=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
fu_19
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 7911    TXN_7420327     CUST_05  Furniture  NaN            29.0       8.0
#
#       Total Spent Payment Method Location Transaction Date Discount Applied
# 7911        232.0    Credit Card   Online       2023-02-24             True

# %%
df.loc[fu_19.index,"Item"]="Item_17_FUR"

# %%
fu_18=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
fu_18
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 9935     TXN_9748964     CUST_24  Furniture  NaN            14.0       2.0
# 10857    TXN_8414334     CUST_23  Furniture  NaN            14.0       8.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 9935          28.0            Cash  In-store       2024-02-21            False
# 10857        112.0  Digital Wallet    Online       2024-11-27             True

# %%
df.loc[fu_18.index,"Item"]="Item_7_FUR"

# %%
fu_17=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
fu_17
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 7535     TXN_3994804     CUST_03  Furniture  NaN            33.5       1.0
# 8386     TXN_1981233     CUST_05  Furniture  NaN            33.5       5.0
# 8455     TXN_6400580     CUST_07  Furniture  NaN            33.5       9.0
# 11312    TXN_9966592     CUST_13  Furniture  NaN            33.5       7.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 7535          33.5     Credit Card  In-store       2022-01-08              NaN
# 8386         167.5  Digital Wallet  In-store       2023-08-06             True
# 8455         301.5     Credit Card    Online       2023-09-11            False
# 11312        234.5            Cash  In-store       2022-05-17              NaN

# %%
df.loc[fu_17.index,"Item"]="Item_20_FUR"

# %%
fu_16=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
fu_16
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 3348     TXN_5773308     CUST_07  Furniture  NaN            17.0       5.0
# 10210    TXN_3961088     CUST_04  Furniture  NaN            17.0       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 3348          85.0     Credit Card    Online       2024-01-01             True
# 10210         34.0  Digital Wallet  In-store       2023-03-23             True

# %%
df.loc[fu_16.index,"Item"]="Item_9_FUR"

# %%
fu_15=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
fu_15
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 6697     TXN_1211345     CUST_19  Furniture  NaN             9.5       7.0
# 9751     TXN_2595449     CUST_02  Furniture  NaN             9.5      10.0
# 10280    TXN_8628417     CUST_09  Furniture  NaN             9.5       5.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 6697          66.5  Digital Wallet    Online       2024-12-02              NaN
# 9751          95.0            Cash    Online       2024-07-08             True
# 10280         47.5  Digital Wallet  In-store       2022-10-09             True

# %%
df.loc[fu_15.index,"Item"]="Item_4_FUR"

# %%
fu_14=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
fu_14
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 3243    TXN_8717697     CUST_20  Furniture  NaN            20.0       6.0
# 6367    TXN_8630147     CUST_11  Furniture  NaN            20.0      10.0
# 7258    TXN_2691217     CUST_17  Furniture  NaN            20.0       2.0
#
#       Total Spent Payment Method  Location Transaction Date Discount Applied
# 3243        120.0           Cash  In-store       2024-05-21            False
# 6367        200.0           Cash  In-store       2024-02-28             True
# 7258         40.0    Credit Card    Online       2024-08-11             True

# %%
df.loc[fu_14.index,"Item"]="Item_11_FUR"

# %%
fu_13=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
fu_13
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 2898    TXN_4554250     CUST_23  Furniture  NaN            41.0       6.0
# 7826    TXN_2457102     CUST_18  Furniture  NaN            41.0       3.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2898        246.0     Credit Card  In-store       2022-10-19            False
# 7826        123.0  Digital Wallet    Online       2022-03-10             True

# %%
df.loc[fu_13.index,"Item"]="Item_25_FUR"

# %%
fu_12=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==18.5) & (df["Item"].isnull())]
fu_12
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 4433    TXN_5509504     CUST_02  Furniture  NaN            18.5       4.0
# 6225    TXN_5310579     CUST_18  Furniture  NaN            18.5      10.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 4433         74.0  Digital Wallet    Online       2023-06-20             True
# 6225        185.0  Digital Wallet  In-store       2024-07-02              NaN

# %%
df.loc[fu_12.index,"Item"]="Item_10_FUR"

# %%
fu_11=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==12.5) & (df["Item"].isnull())]
fu_11
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 3378    TXN_3214105     CUST_23  Furniture  NaN            12.5       9.0
#
#       Total Spent  Payment Method Location Transaction Date Discount Applied
# 3378        112.5  Digital Wallet   Online       2024-07-05             True

# %%
df.loc[fu_11.index,"Item"]="Item_6_FUR"

# %%
fu_1=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
fu_1
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 354      TXN_7043807     CUST_24  Furniture  NaN            26.0       7.0
# 1084     TXN_4614873     CUST_03  Furniture  NaN            26.0       9.0
# 10537    TXN_4422875     CUST_23  Furniture  NaN            26.0       2.0
# 10824    TXN_2809812     CUST_15  Furniture  NaN            26.0       9.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 354          182.0  Digital Wallet  In-store       2022-02-07              NaN
# 1084         234.0            Cash    Online       2023-07-29            False
# 10537         52.0  Digital Wallet  In-store       2023-10-01            False
# 10824        234.0     Credit Card  In-store       2022-09-01             True

# %%
df.loc[fu_1.index,"Item"]="	Item_15_FUR"

# %%
fu_2=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
fu_2
# Out:
#     Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 419    TXN_2687566     CUST_19  Furniture  NaN            27.5       1.0
# 870    TXN_3278532     CUST_07  Furniture  NaN            27.5       9.0
#
#      Total Spent Payment Method  Location Transaction Date Discount Applied
# 419         27.5    Credit Card    Online       2022-03-21            False
# 870        247.5           Cash  In-store       2025-01-12            False

# %%
df.loc[fu_2.index,"Item"]="Item_16_FUR"

# %%
fu_3=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==38.0) & (df["Item"].isnull())]
fu_3
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 542      TXN_8177929     CUST_12  Furniture  NaN            38.0       2.0
# 1420     TXN_4036118     CUST_06  Furniture  NaN            38.0       6.0
# 2476     TXN_3347015     CUST_24  Furniture  NaN            38.0       7.0
# 3177     TXN_9102221     CUST_13  Furniture  NaN            38.0       2.0
# 11352    TXN_4654556     CUST_20  Furniture  NaN            38.0       9.0
# 12123    TXN_7745199     CUST_13  Furniture  NaN            38.0       9.0
# 12386    TXN_4266749     CUST_11  Furniture  NaN            38.0       7.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 542           76.0     Credit Card    Online       2022-06-12             True
# 1420         228.0            Cash  In-store       2023-01-28              NaN
# 2476         266.0     Credit Card    Online       2024-08-25            False
# ...

# %%
df.loc[fu_3.index,"Item"]="Item_23_FUR"

# %%
fu_4=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
fu_4
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 699     TXN_5849098     CUST_16  Furniture  NaN            35.0       3.0
# 2139    TXN_8233871     CUST_04  Furniture  NaN            35.0       9.0
# 5238    TXN_6376468     CUST_24  Furniture  NaN            35.0       3.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 699         105.0            Cash    Online       2024-06-23            False
# 2139        315.0  Digital Wallet  In-store       2023-07-19             True
# 5238        105.0            Cash  In-store       2023-06-05            False

# %%
df.loc[fu_4.index,"Item"]="Item_21_FUR"

# %%
fu_5=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==5.0) & (df["Item"].isnull())]
fu_5
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 700     TXN_3010762     CUST_24  Furniture  NaN             5.0       2.0
# 9010    TXN_9321451     CUST_10  Furniture  NaN             5.0       1.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 700          10.0  Digital Wallet  In-store       2023-07-14             True
# 9010          5.0     Credit Card    Online       2022-11-21              NaN

# %%
df.loc[fu_5.index,"Item"]="Item_1_FUR"

# %%
fu_6=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
fu_6
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 885      TXN_3512388     CUST_14  Furniture  NaN            11.0      10.0
# 3420     TXN_5965620     CUST_23  Furniture  NaN            11.0       4.0
# 5266     TXN_1791231     CUST_16  Furniture  NaN            11.0       5.0
# 6871     TXN_3707017     CUST_10  Furniture  NaN            11.0       3.0
# 7044     TXN_7303362     CUST_20  Furniture  NaN            11.0      10.0
# 7252     TXN_8221789     CUST_23  Furniture  NaN            11.0      10.0
# 10095    TXN_3829639     CUST_20  Furniture  NaN            11.0       2.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 885          110.0  Digital Wallet  In-store       2024-03-30              NaN
# 3420          44.0     Credit Card  In-store       2022-06-13            False
# 5266          55.0     Credit Card    Online       2024-04-21            False
# ...

# %%
df.loc[fu_6.index,"Item"]="Item_5_FUR"

# %%
fu_7=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
fu_7
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 1130    TXN_5431616     CUST_17  Furniture  NaN            15.5       1.0
# 1427    TXN_3133019     CUST_21  Furniture  NaN            15.5       9.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1130         15.5            Cash  In-store       2024-11-26            False
# 1427        139.5  Digital Wallet    Online       2024-01-01             True

# %%
df.loc[fu_7.index,"Item"]="Item_8_FUR"

# %%
fu_8=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
fu_8
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 2007     TXN_2292675     CUST_22  Furniture  NaN             6.5       1.0
# 3830     TXN_6106136     CUST_07  Furniture  NaN             6.5       9.0
# 6329     TXN_4181548     CUST_02  Furniture  NaN             6.5       9.0
# 10033    TXN_5445578     CUST_11  Furniture  NaN             6.5       8.0
# 11353    TXN_4279707     CUST_19  Furniture  NaN             6.5       2.0
# 12025    TXN_7062557     CUST_03  Furniture  NaN             6.5       5.0
# 12143    TXN_4297692     CUST_15  Furniture  NaN             6.5       6.0
# 12435    TXN_5147764     CUST_01  Furniture  NaN             6.5       5.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 2007           6.5  Digital Wallet    Online       2024-06-23              NaN
# 3830          58.5     Credit Card  In-store       2024-02-03            False
# ...

# %%
df.loc[fu_8.index,"Item"]="Item_2_FUR"

# %%
fu_9=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==32.0) & (df["Item"].isnull())]
fu_9
# Out:
#      Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 6393    TXN_2773543     CUST_07  Furniture  NaN            32.0      10.0
# 8503    TXN_2190232     CUST_06  Furniture  NaN            32.0       7.0
# 9723    TXN_3277863     CUST_17  Furniture  NaN            32.0       7.0
#
#       Total Spent  Payment Method  Location Transaction Date Discount Applied
# 6393        320.0            Cash    Online       2023-01-22              NaN
# 8503        224.0  Digital Wallet  In-store       2024-02-16            False
# 9723        224.0     Credit Card    Online       2022-12-16            False

# %%
df.loc[fu_9.index,"Item"]="Item_19_FUR"

# %%
fu_10=df[(df["Category"]=="Furniture") & (df["Price Per Unit"]==39.5) & (df["Item"].isnull())]
fu_10
# Out:
#       Transaction ID Customer ID   Category Item  Price Per Unit  Quantity  \
# 1331     TXN_2227872     CUST_03  Furniture  NaN            39.5       7.0
# 6971     TXN_5533205     CUST_18  Furniture  NaN            39.5       7.0
# 7694     TXN_8475688     CUST_05  Furniture  NaN            39.5       4.0
# 11931    TXN_5657839     CUST_24  Furniture  NaN            39.5       5.0
#
#        Total Spent  Payment Method  Location Transaction Date Discount Applied
# 1331         276.5  Digital Wallet  In-store       2024-05-27             True
# 6971         276.5     Credit Card    Online       2023-12-31              NaN
# 7694         158.0     Credit Card  In-store       2023-05-20            False
# 11931        197.5     Credit Card    Online       2024-04-01              NaN

# %%
df.loc[fu_10.index,"Item"]="Item_24_FUR"

# %%
c_25=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==36.5) & (df["Item"].isnull())]
c_25
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 6327    TXN_1505827     CUST_13  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 6327            36.5       3.0        109.5  Digital Wallet   Online
#
#      Transaction Date Discount Applied
# 6327       2025-01-18              NaN

# %%
df.loc[c_25.index,"Item"]="Item_22_CEA"

# %%
c_24=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==35.0) & (df["Item"].isnull())]
c_24
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 2104     TXN_5664358     CUST_07  Computers and electric accessories  NaN
# 3027     TXN_6688533     CUST_16  Computers and electric accessories  NaN
# 4288     TXN_9493702     CUST_06  Computers and electric accessories  NaN
# 10323    TXN_2701654     CUST_21  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2104             35.0       1.0         35.0     Credit Card    Online
# 3027             35.0       1.0         35.0  Digital Wallet    Online
# 4288             35.0       6.0        210.0            Cash    Online
# 10323            35.0       1.0         35.0     Credit Card  In-store
#
#       Transaction Date Discount Applied
# 2104        2022-01-04            False
# 3027        2023-11-09              NaN
# 4288        2023-09-14              NaN
# 10323       2022-01-06              NaN

# %%
df.loc[c_24.index,"Item"]="Item_21_CEA"

# %%
c_23=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==29.0) & (df["Item"].isnull())]
c_23
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 1877    TXN_7869463     CUST_14  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent Payment Method Location  \
# 1877            29.0       8.0        232.0    Credit Card   Online
#
#      Transaction Date Discount Applied
# 1877       2023-03-11            False

# %%
df.loc[c_23.index,"Item"]="Item_17_CEA"

# %%
c_22=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==18.5) & (df["Item"].isnull())]
c_22
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 2083    TXN_5513567     CUST_06  Computers and electric accessories  NaN
# 4529    TXN_8209444     CUST_10  Computers and electric accessories  NaN
# 5045    TXN_4837386     CUST_09  Computers and electric accessories  NaN
# 6632    TXN_1046367     CUST_21  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2083            18.5      10.0        185.0  Digital Wallet    Online
# 4529            18.5       2.0         37.0            Cash  In-store
# 5045            18.5       4.0         74.0            Cash    Online
# 6632            18.5      10.0        185.0            Cash  In-store
#
#      Transaction Date Discount Applied
# 2083       2022-10-13              NaN
# 4529       2024-10-31             True
# 5045       2022-01-10            False
# 6632       2022-06-21              NaN

# %%
df.loc[c_22.index,"Item"]="Item_10_CEA"

# %%
c_21=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==27.5) & (df["Item"].isnull())]
c_21
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 1504    TXN_7920383     CUST_15  Computers and electric accessories  NaN
# 8139    TXN_6051216     CUST_07  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent Payment Method  Location  \
# 1504            27.5       4.0        110.0           Cash  In-store
# 8139            27.5      10.0        275.0    Credit Card    Online
#
#      Transaction Date Discount Applied
# 1504       2023-12-24             True
# 8139       2022-09-23            False

# %%
df.loc[c_21.index,"Item"]="Item_16_CEA"

# %%
c_20=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==41.0) & (df["Item"].isnull())]
c_20
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 5745    TXN_3855536     CUST_04  Computers and electric accessories  NaN
# 6919    TXN_6912528     CUST_08  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent Payment Method  Location  \
# 5745            41.0      10.0        410.0    Credit Card  In-store
# 6919            41.0       7.0        287.0           Cash    Online
#
#      Transaction Date Discount Applied
# 5745       2024-09-27             True
# 6919       2024-04-13              NaN

# %%
df.loc[c_20.index,"Item"]="Item_25_CEA"

# %%
c_19=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==24.5) & (df["Item"].isnull())]  
c_19
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 2685    TXN_2810459     CUST_09  Computers and electric accessories  NaN
# 6416    TXN_6720124     CUST_09  Computers and electric accessories  NaN
# 9246    TXN_2715374     CUST_12  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2685            24.5       1.0         24.5            Cash  In-store
# 6416            24.5       8.0        196.0  Digital Wallet  In-store
# 9246            24.5       7.0        171.5     Credit Card  In-store
#
#      Transaction Date Discount Applied
# 2685       2022-04-19              NaN
# 6416       2022-07-19            False
# 9246       2023-03-15             True

# %%
df.loc[c_19.index,"Item"]="Item_14_CEA"

# %%
c_18=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==12.5) & (df["Item"].isnull())]
c_18
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 3447    TXN_1972506     CUST_09  Computers and electric accessories  NaN
# 4594    TXN_4563119     CUST_06  Computers and electric accessories  NaN
# 6385    TXN_6179719     CUST_08  Computers and electric accessories  NaN
# 8335    TXN_2559484     CUST_04  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 3447            12.5       8.0        100.0            Cash    Online
# 4594            12.5       8.0        100.0            Cash    Online
# 6385            12.5       4.0         50.0  Digital Wallet  In-store
# 8335            12.5       9.0        112.5            Cash  In-store
#
#      Transaction Date Discount Applied
# 3447       2024-12-14              NaN
# 4594       2023-01-03             True
# 6385       2022-03-29            False
# 8335       2022-04-15              NaN

# %%
df.loc[c_18.index,"Item"]="Item_6_CEA"

# %%
c_17=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==26.0) & (df["Item"].isnull())]
c_17
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 3053     TXN_5601162     CUST_22  Computers and electric accessories  NaN
# 5953     TXN_7375053     CUST_04  Computers and electric accessories  NaN
# 9514     TXN_7929084     CUST_15  Computers and electric accessories  NaN
# 9788     TXN_6970868     CUST_20  Computers and electric accessories  NaN
# 10695    TXN_5044258     CUST_04  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 3053             26.0       1.0         26.0            Cash  In-store
# 5953             26.0       1.0         26.0  Digital Wallet    Online
# 9514             26.0       1.0         26.0            Cash    Online
# 9788             26.0       9.0        234.0            Cash    Online
# 10695            26.0      10.0        260.0  Digital Wallet    Online
#
#       Transaction Date Discount Applied
# 3053        2022-01-26             True
# ...

# %%
df.loc[c_17.index,"Item"]="Item_15_CEA"

# %%
c_16=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==9.5) & (df["Item"].isnull())]
c_16
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 10934    TXN_3947387     CUST_17  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 10934             9.5       7.0         66.5  Digital Wallet   Online
#
#       Transaction Date Discount Applied
# 10934       2023-12-13            False

# %%
df.loc[c_16.index,"Item"]="Item_4_CEA"

# %%
c_15=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==33.5) & (df["Item"].isnull())]
c_15
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 1341     TXN_9285106     CUST_23  Computers and electric accessories  NaN
# 1403     TXN_8831517     CUST_08  Computers and electric accessories  NaN
# 10982    TXN_8917078     CUST_18  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent Payment Method  Location  \
# 1341             33.5      10.0        335.0    Credit Card  In-store
# 1403             33.5       1.0         33.5           Cash  In-store
# 10982            33.5       8.0        268.0    Credit Card    Online
#
#       Transaction Date Discount Applied
# 1341        2024-06-18             True
# 1403        2022-04-21             True
# 10982       2022-10-15            False

# %%
df.loc[c_15.index,"Item"]="Item_22_CEA"

# %%
c_14=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==38.0) & (df["Item"].isnull())]
c_14
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 2363     TXN_3130278     CUST_01  Computers and electric accessories  NaN
# 2463     TXN_2589028     CUST_16  Computers and electric accessories  NaN
# 11113    TXN_9719161     CUST_21  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2363             38.0       8.0        304.0     Credit Card    Online
# 2463             38.0       2.0         76.0  Digital Wallet    Online
# 11113            38.0       8.0        304.0            Cash  In-store
#
#       Transaction Date Discount Applied
# 2363        2022-12-23              NaN
# 2463        2022-06-05             True
# 11113       2024-09-11              NaN

# %%
df.loc[c_14.index,"Item"]="Item_23_CEA"

# %%
c_13=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==21.5) & (df["Item"].isnull())]
c_13
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 3134     TXN_3489467     CUST_23  Computers and electric accessories  NaN
# 4055     TXN_5458562     CUST_21  Computers and electric accessories  NaN
# 5879     TXN_6269570     CUST_25  Computers and electric accessories  NaN
# 9640     TXN_7744516     CUST_04  Computers and electric accessories  NaN
# 11084    TXN_9576872     CUST_01  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 3134             21.5       7.0        150.5     Credit Card  In-store
# 4055             21.5       6.0        129.0  Digital Wallet  In-store
# 5879             21.5       6.0        129.0  Digital Wallet    Online
# 9640             21.5      10.0        215.0     Credit Card  In-store
# 11084            21.5       3.0         64.5            Cash  In-store
#
#       Transaction Date Discount Applied
# 3134        2023-10-15             True
# ...

# %%
df.loc[c_13.index,"Item"]="Item_12_CEA"

# %%
c_12=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==17.0) & (df["Item"].isnull())]
c_12
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 2980     TXN_8373559     CUST_23  Computers and electric accessories  NaN
# 6458     TXN_9823408     CUST_05  Computers and electric accessories  NaN
# 8029     TXN_5592249     CUST_07  Computers and electric accessories  NaN
# 11264    TXN_5635056     CUST_04  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2980             17.0       3.0         51.0  Digital Wallet    Online
# 6458             17.0       3.0         51.0            Cash  In-store
# 8029             17.0       8.0        136.0            Cash  In-store
# 11264            17.0       6.0        102.0            Cash    Online
#
#       Transaction Date Discount Applied
# 2980        2022-11-19            False
# 6458        2024-10-20              NaN
# 8029        2023-03-14             True
# 11264       2023-04-24             True

# %%
df.loc[c_12.index,"Item"]="Item_9_CEA"

# %%
c_11=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==14.0) & (df["Item"].isnull())]
c_11
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 1463     TXN_2911719     CUST_02  Computers and electric accessories  NaN
# 4025     TXN_5141030     CUST_11  Computers and electric accessories  NaN
# 4059     TXN_5984083     CUST_20  Computers and electric accessories  NaN
# 5326     TXN_8514486     CUST_06  Computers and electric accessories  NaN
# 7410     TXN_5341574     CUST_01  Computers and electric accessories  NaN
# 10530    TXN_1525936     CUST_20  Computers and electric accessories  NaN
# 12074    TXN_6198629     CUST_15  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 1463             14.0       4.0         56.0            Cash    Online
# 4025             14.0       9.0        126.0            Cash  In-store
# 4059             14.0       6.0         84.0     Credit Card  In-store
# 5326             14.0       8.0        112.0  Digital Wallet  In-store
# ...

# %%
df.loc[c_11.index,"Item"]="Item_7_CEA"

# %%
c_10=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==5.0) & (df["Item"].isnull())]
c_10
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 9863    TXN_2357597     CUST_21  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent Payment Method Location  \
# 9863             5.0       3.0         15.0           Cash   Online
#
#      Transaction Date Discount Applied
# 9863       2024-04-17             True

# %%
df.loc[c_10.index,"Item"]="Item_1_CEA"

# %%
c_9=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==39.5) & (df["Item"].isnull())]
c_9
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 6690    TXN_6568038     CUST_05  Computers and electric accessories  NaN
# 8931    TXN_8693268     CUST_19  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 6690            39.5       2.0         79.0  Digital Wallet  In-store
# 8931            39.5       5.0        197.5     Credit Card  In-store
#
#      Transaction Date Discount Applied
# 6690       2023-12-16              NaN
# 8931       2022-05-31              NaN

# %%
df.loc[c_9.index,"Item"]="Item_24_CEA"

# %%
c_8=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==32.0) & (df["Item"].isnull())]
c_8
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 385     TXN_2218629     CUST_10  Computers and electric accessories  NaN
# 1322    TXN_3394201     CUST_17  Computers and electric accessories  NaN
# 2020    TXN_2511487     CUST_24  Computers and electric accessories  NaN
# 5409    TXN_7966995     CUST_14  Computers and electric accessories  NaN
# 7402    TXN_9285109     CUST_20  Computers and electric accessories  NaN
# 8481    TXN_3878879     CUST_03  Computers and electric accessories  NaN
# 8977    TXN_2004814     CUST_16  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 385             32.0       3.0         96.0     Credit Card    Online
# 1322            32.0       8.0        256.0            Cash    Online
# 2020            32.0      10.0        320.0     Credit Card    Online
# 5409            32.0       8.0        256.0  Digital Wallet    Online
# ...

# %%
df.loc[c_8.index,"Item"]="Item_19_CEA"

# %%
c_7=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==6.5) & (df["Item"].isnull())]
c_7
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 5833    TXN_2633599     CUST_10  Computers and electric accessories  NaN
# 7151    TXN_2463351     CUST_19  Computers and electric accessories  NaN
# 7748    TXN_1306295     CUST_15  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method Location  \
# 5833             6.5       8.0         52.0            Cash   Online
# 7151             6.5      10.0         65.0     Credit Card   Online
# 7748             6.5       5.0         32.5  Digital Wallet   Online
#
#      Transaction Date Discount Applied
# 5833       2024-01-16             True
# 7151       2022-08-12              NaN
# 7748       2022-09-13             True

# %%
df.loc[c_7.index,"Item"]="Item_2_CEA"

# %%
c_6=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==15.5) & (df["Item"].isnull())]
c_6
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 2339     TXN_2245624     CUST_12  Computers and electric accessories  NaN
# 3963     TXN_7513847     CUST_07  Computers and electric accessories  NaN
# 7117     TXN_3275587     CUST_04  Computers and electric accessories  NaN
# 7763     TXN_9478594     CUST_12  Computers and electric accessories  NaN
# 12164    TXN_1201215     CUST_13  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 2339             15.5       4.0         62.0            Cash    Online
# 3963             15.5       2.0         31.0  Digital Wallet    Online
# 7117             15.5       5.0         77.5     Credit Card  In-store
# 7763             15.5       7.0        108.5     Credit Card    Online
# 12164            15.5       6.0         93.0            Cash    Online
#
#       Transaction Date Discount Applied
# 2339        2022-07-10            False
# ...

# %%
df.loc[c_6.index,"Item"]="Item_8_CEA"

# %%
c_5=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==30.5) & (df["Item"].isnull())]
c_5
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 9901     TXN_9020139     CUST_19  Computers and electric accessories  NaN
# 12337    TXN_6292699     CUST_18  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 9901             30.5       2.0         61.0  Digital Wallet  In-store
# 12337            30.5       8.0        244.0     Credit Card  In-store
#
#       Transaction Date Discount Applied
# 9901        2024-04-15              NaN
# 12337       2025-01-14              NaN

# %%
df.loc[c_5.index,"Item"]="Item_18_CEA"

# %%
c_4=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==20.0) & (df["Item"].isnull())]
c_4
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 12477    TXN_5625684     CUST_22  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent Payment Method  Location  \
# 12477            20.0       4.0         80.0           Cash  In-store
#
#       Transaction Date Discount Applied
# 12477       2022-11-09             True

# %%
df.loc[c_4.index,"Item"]="Item_11_CEA"

# %%
c_3=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==23.0) & (df["Item"].isnull())]
c_3
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 837     TXN_6857566     CUST_23  Computers and electric accessories  NaN
# 4951    TXN_9580803     CUST_14  Computers and electric accessories  NaN
# 5574    TXN_8539518     CUST_24  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent Payment Method  Location  \
# 837             23.0       2.0         46.0    Credit Card  In-store
# 4951            23.0       5.0        115.0           Cash  In-store
# 5574            23.0       8.0        184.0           Cash    Online
#
#      Transaction Date Discount Applied
# 837        2024-03-14             True
# 4951       2023-07-13              NaN
# 5574       2022-03-31            False

# %%
df.loc[c_3.index,"Item"]="Item_13_CEA"

# %%
c_2=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==11.0) & (df["Item"].isnull())]
c_2
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 820      TXN_8487838     CUST_18  Computers and electric accessories  NaN
# 1146     TXN_6308565     CUST_19  Computers and electric accessories  NaN
# 4804     TXN_9035158     CUST_17  Computers and electric accessories  NaN
# 10019    TXN_9333110     CUST_15  Computers and electric accessories  NaN
#
#        Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 820              11.0       4.0         44.0  Digital Wallet    Online
# 1146             11.0       4.0         44.0     Credit Card    Online
# 4804             11.0       2.0         22.0  Digital Wallet  In-store
# 10019            11.0       2.0         22.0            Cash  In-store
#
#       Transaction Date Discount Applied
# 820         2023-02-04              NaN
# 1146        2024-02-10            False
# 4804        2022-07-28            False
# 10019       2024-07-03            False

# %%
df.loc[c_2.index,"Item"]="Item_5_CEA"

# %%
c_1=df[(df["Category"]=="Computers and electric accessories") & (df["Price Per Unit"]==8.0) & (df["Item"].isnull())]
c_1
# Out:
#      Transaction ID Customer ID                            Category Item  \
# 1045    TXN_8454077     CUST_11  Computers and electric accessories  NaN
# 7740    TXN_6929636     CUST_17  Computers and electric accessories  NaN
# 8768    TXN_2018105     CUST_13  Computers and electric accessories  NaN
#
#       Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 1045             8.0       2.0         16.0            Cash    Online
# 7740             8.0       2.0         16.0  Digital Wallet    Online
# 8768             8.0      10.0         80.0     Credit Card  In-store
#
#      Transaction Date Discount Applied
# 1045       2023-02-15             True
# 7740       2023-11-23              NaN
# 8768       2023-10-07            False

# %%
df.loc[c_1.index,"Item"]="Item_3_CEA"

# %%
df["Transaction Date"]=pd.to_datetime(df["Transaction Date"])

# %%
df.isna().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                   0
# Price Per Unit         0
# Quantity               0
# Total Spent            0
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    3988
# dtype: int64

# %%
payment_method_used=df["Payment Method"].value_counts()
plt.pie(payment_method_used,labels=payment_method_used.index,autopct="%1.1f%%")
plt.show()

# %%
Sales_by_location=df.groupby("Location")["Total Spent"].sum()
plt.figure(figsize=(4,3))
plt.bar(Sales_by_location.index,Sales_by_location.values,width=0.6,
        edgecolor="black",linewidth=2,
        tick_label=Sales_by_location.index)
plt.title("Sales by Location")
plt.xlabel("Location")
plt.ylabel("Total Spent")
plt.show()

# %%
df
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 11966    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 11967    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 11968    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 11969    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 11970    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...
